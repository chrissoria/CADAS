# %%
import os,glob
import pandas as pd
import numpy as np

# %%
current_directory = "/Users/chrissoria/Documents/Research/CADAS_Data_Export"

os.chdir(current_directory)

print(current_directory)
# Out:
# /Users/chrissoria/Documents/Research/CADAS_Data_Export

# %% [markdown]
# This is what I want to produce: generate new_string_var = cond(old_numeric_var == 0, "correct", cond(old_numeric_var == 1, "incorrect", ""))

# %%
Cog = (
    pd.read_excel("../CADAS/CADAS_DD_V5.xlsx", engine='openpyxl', sheet_name="Cognitive")  # replace with your file path
    .loc[lambda df: df['Field_Type'] == 'Option', ['Field_Type', 'Name', 'Special_Info']]
    .reset_index(drop=True)
)

Cog['Special_Info'] = Cog['Special_Info'].str.lower()
Cog['Name'] = Cog['Name'].str.lower()
Cog['Special_Info'] = Cog['Special_Info'].str.replace(' required', '', case=False)

columns_to_process = ['Field_Type', 'Name', 'Special_Info']

for col in columns_to_process:
    Cog[col] = Cog[col].astype(str).str.strip()
    
Cog['Name_Cap'] = Cog['Name'].str.upper()

split_special_info = Cog['Special_Info'].str.split(',', expand=True)
split_special_info = split_special_info.applymap(lambda x: x.strip() if x is not None else None)

Cog = pd.concat([Cog, split_special_info], axis=1)

Cog = Cog.replace({None: np.nan})

for i in range(0, 6):
    Cog[f'new_column{i}'] = Cog.apply(lambda row: str(f'cond({row["Name"]} ==  {Cog.columns[i+4]}, "{row[i]}", '), axis=1).astype(str)

    Cog['new_combined_column'] = ""

for i in range(0, 6):
    Cog['new_combined_column'] += Cog.apply(lambda row: row[f"new_column{i}"] if 'nan' not in str(row[f"new_column{i}"]).lower() else '', axis=1)
    
Cog["generate"] = Cog.apply(lambda row: f'generate {row["Name_Cap"]} = {row["new_combined_column"]}""))', axis=1)

Cog["generate"] = Cog["generate"].apply(lambda x: x + ")" if "2," in str(x) else x)
Cog["generate"] = Cog["generate"].apply(lambda x: x + ")" if "3," in str(x) else x)
Cog["generate"] = Cog["generate"].apply(lambda x: x + ")" if "4," in str(x) else x)
Cog["generate"] = Cog["generate"].apply(lambda x: x + ")" if "5," in str(x) else x)
Cog["generate"] = Cog["generate"].apply(lambda x: x + ")" if "6," in str(x) else x)
Cog["generate"] = Cog["generate"].apply(lambda x: x + ")" if "7," in str(x) else x)
Cog["generate"] = Cog["generate"].apply(lambda x: x + ")" if "8," in str(x) else x)
Cog["generate"] = Cog["generate"].apply(lambda x: x + ")" if "9," in str(x) else x)
Cog["generate"] = Cog["generate"].apply(lambda x: x + ")" if "10," in str(x) else x)
Cog["generate"] = Cog["generate"].apply(lambda x: x + ")" if "11," in str(x) else x)
Cog["generate"] = Cog["generate"].apply(lambda x: x + ")" if "12," in str(x) else x)
Cog["generate"] = Cog["generate"].apply(lambda x: x + ")" if "13," in str(x) else x)

Cog["drop"] = Cog.apply(lambda row: f'drop {row["Name"]}', axis=1)
Cog["full_instruction"] = Cog.apply(lambda row: f'{row["generate"]}\n\n{row["drop"]}', axis=1)

Cog_file = '../CADAS/recode_files/Cog_to_numeric.txt'
with open(Cog_file, 'w') as f:
    for code_line in Cog['full_instruction']:
        f.write(f"{code_line}\n\n")
        
Cog.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_47575/976896188.py in <module>
#       1 Cog = (
# ----> 2     pd.read_excel("../CADAS/CADAS_DD_V5.xlsx", engine='openpyxl', sheet_name="Cognitive")  # replace with your file path
#       3     .loc[lambda df: df['Field_Type'] == 'Option', ['Field_Type', 'Name', 'Special_Info']]
#       4     .reset_index(drop=True)
#       5 )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
# ...

# %%
Socio = (
    pd.read_excel("../CADAS/CADAS_DD_V4.xlsx", engine='openpyxl', sheet_name="Sociodemographic")  # replace with your file path
    .loc[lambda df: df['Field_Type'] == 'Option', ['Field_Type', 'Name', 'Special_Info']]
    .reset_index(drop=True)
)

Socio['Special_Info'] = Socio['Special_Info'].str.lower()
Socio['Name'] = Socio['Name'].str.lower()
Socio['Special_Info'] = Socio['Special_Info'].str.replace(' required', '', case=False)

columns_to_process = ['Field_Type', 'Name', 'Special_Info']

for col in columns_to_process:
    Socio[col] = Socio[col].astype(str).str.strip()
    
Socio['Name_Cap'] = Socio['Name'].str.upper()

split_special_info = Socio['Special_Info'].str.split(',', expand=True)
split_special_info = split_special_info.applymap(lambda x: x.strip() if x is not None else None)

Socio = pd.concat([Socio, split_special_info], axis=1)

Socio = Socio.replace({None: np.nan})

for i in range(0, 14):
    Socio[f'new_column{i}'] = Socio.apply(lambda row: str(f'cond({row["Name"]} ==  {Socio.columns[i+4]}, "{row[i]}", '), axis=1).astype(str)

    Socio['new_combined_column'] = ""

for i in range(0, 14):
    Socio['new_combined_column'] += Socio.apply(lambda row: row[f"new_column{i}"] if 'nan' not in str(row[f"new_column{i}"]).lower() else '', axis=1)
    
Socio["generate"] = Socio.apply(lambda row: f'generate {row["Name_Cap"]} = {row["new_combined_column"]}""))', axis=1)

Socio["generate"] = Socio["generate"].apply(lambda x: x + ")" if "2," in str(x) else x)
Socio["generate"] = Socio["generate"].apply(lambda x: x + ")" if "3," in str(x) else x)
Socio["generate"] = Socio["generate"].apply(lambda x: x + ")" if "4," in str(x) else x)
Socio["generate"] = Socio["generate"].apply(lambda x: x + ")" if "5," in str(x) else x)
Socio["generate"] = Socio["generate"].apply(lambda x: x + ")" if "6," in str(x) else x)
Socio["generate"] = Socio["generate"].apply(lambda x: x + ")" if "7," in str(x) else x)
Socio["generate"] = Socio["generate"].apply(lambda x: x + ")" if "8," in str(x) else x)
Socio["generate"] = Socio["generate"].apply(lambda x: x + ")" if "9," in str(x) else x)
Socio["generate"] = Socio["generate"].apply(lambda x: x + ")" if "10," in str(x) else x)
Socio["generate"] = Socio["generate"].apply(lambda x: x + ")" if "11," in str(x) else x)
Socio["generate"] = Socio["generate"].apply(lambda x: x + ")" if "12," in str(x) else x)
Socio["generate"] = Socio["generate"].apply(lambda x: x + ")" if "13," in str(x) else x)

Socio["drop"] = Socio.apply(lambda row: f'drop {row["Name"]}', axis=1)
Socio["full_instruction"] = Socio.apply(lambda row: f'{row["generate"]}\n\n{row["drop"]}', axis=1)

Socio_file = '../CADAS/recode_files/Socio_to_numeric.txt'
with open(Socio_file, 'w') as f:
    for code_line in Socio['full_instruction']:
        f.write(f"{code_line}\n\n")
        
Socio.head()
# Out:
#   Field_Type     Name                                       Special_Info  \
# 0     Option  s_1_1_p  negro(a) ,mulato(a) mezclado(a) o trigueño (bl...
# 1     Option  s_1_1_d  negro(a) ,mulato(a),blanco(a) ,indio(a),otra,n...
# 2     Option  s_1_1_c  negro(a),blanco(a),mulato(a) / mestizo(a),otra...
# 3     Option    s_2_9  nunca se ha casado ,casado/union consensual ,v...
# 4     Option   s_2_11  agnóstico/ateo ,católico romano ,evangélico / ...
#
#   Name_Cap                   0  \
# 0  S_1_1_P            negro(a)
# 1  S_1_1_D            negro(a)
# 2  S_1_1_C            negro(a)
# 3    S_2_9  nunca se ha casado
# 4   S_2_11      agnóstico/ateo
#
#                                                    1  \
# 0  mulato(a) mezclado(a) o trigueño (blanco o negro)
# 1                                          mulato(a)
# 2                                          blanco(a)
# 3                            casado/union consensual
# 4                                    católico romano
#
# ...

# %%
Infor = (
    pd.read_excel("../CADAS/CADAS_DD_V4.xlsx", engine='openpyxl', sheet_name="Informant")  # replace with your file path
    .loc[lambda df: df['Field_Type'] == 'Option', ['Field_Type', 'Name', 'Special_Info']]
    .reset_index(drop=True)
)

Infor['Special_Info'] = Infor['Special_Info'].str.lower()
Infor['Name'] = Infor['Name'].str.lower()
Infor['Special_Info'] = Infor['Special_Info'].str.replace(' required', '', case=False)

columns_to_process = ['Field_Type', 'Name', 'Special_Info']

for col in columns_to_process:
    Infor[col] = Infor[col].astype(str).str.strip()
    
Infor['Name_Cap'] = Infor['Name'].str.upper()

split_special_info = Infor['Special_Info'].str.split(',', expand=True)
split_special_info = split_special_info.applymap(lambda x: x.strip() if x is not None else None)

Infor = pd.concat([Infor, split_special_info], axis=1)

Infor = Infor.replace({None: np.nan})

for i in range(0, 9):
    Infor[f'new_column{i}'] = Infor.apply(lambda row: str(f'cond({row["Name"]} ==  {Infor.columns[i+4]}, "{row[i]}", '), axis=1).astype(str)

    Infor['new_combined_column'] = ""

for i in range(0, 9):
    Infor['new_combined_column'] += Infor.apply(lambda row: row[f"new_column{i}"] if 'nan' not in str(row[f"new_column{i}"]).lower() else '', axis=1)
    
Infor["generate"] = Infor.apply(lambda row: f'generate {row["Name_Cap"]} = {row["new_combined_column"]}""))', axis=1)

Infor["generate"] = Infor["generate"].apply(lambda x: x + ")" if "2," in str(x) else x)
Infor["generate"] = Infor["generate"].apply(lambda x: x + ")" if "3," in str(x) else x)
Infor["generate"] = Infor["generate"].apply(lambda x: x + ")" if "4," in str(x) else x)
Infor["generate"] = Infor["generate"].apply(lambda x: x + ")" if "5," in str(x) else x)
Infor["generate"] = Infor["generate"].apply(lambda x: x + ")" if "6," in str(x) else x)
Infor["generate"] = Infor["generate"].apply(lambda x: x + ")" if "7," in str(x) else x)
Infor["generate"] = Infor["generate"].apply(lambda x: x + ")" if "8," in str(x) else x)
Infor["generate"] = Infor["generate"].apply(lambda x: x + ")" if "9," in str(x) else x)
Infor["generate"] = Infor["generate"].apply(lambda x: x + ")" if "10," in str(x) else x)
Infor["generate"] = Infor["generate"].apply(lambda x: x + ")" if "11," in str(x) else x)
Infor["generate"] = Infor["generate"].apply(lambda x: x + ")" if "12," in str(x) else x)
Infor["generate"] = Infor["generate"].apply(lambda x: x + ")" if "13," in str(x) else x)

Infor["drop"] = Infor.apply(lambda row: f'drop {row["Name"]}', axis=1)
Infor["full_instruction"] = Infor.apply(lambda row: f'{row["generate"]}\n\n{row["drop"]}', axis=1)

Infor_file = '../CADAS/recode_files/Infor_to_numeric.txt'
with open(Infor_file, 'w') as f:
    for code_line in Infor['generate']:
        f.write(f"{code_line}\n\n")

Infor.head()
# Out:
#   Field_Type  Name                                       Special_Info  \
# 0     Option  i_a2                          si,no,no responde,no sabe
# 1     Option  i_a3                          si,no,no responde,no sabe
# 2     Option  i_a4                          si,no,no responde,no sabe
# 3     Option  i_b1  miembro del hogar de xxxx?,hijo no-residente d...
# 4     Option  i_b4                            femenino,masculino,otro
#
#   Name_Cap                           0                           1  \
# 0     I_A2                          si                          no
# 1     I_A3                          si                          no
# 2     I_A4                          si                          no
# 3     I_B1  miembro del hogar de xxxx?  hijo no-residente de xxxx?
# 4     I_B4                    femenino                   masculino
#
#              2        3    4    5  ...                       new_column2  \
# ...

# %%
Phys = (
    pd.read_excel("../CADAS/CADAS_DD_V4.xlsx", engine='openpyxl', sheet_name="Physical_Exam")  # replace with your file path
    .loc[lambda df: df['Field_Type'] == 'Option', ['Field_Type', 'Name', 'Special_Info']]
    .reset_index(drop=True)
)

Phys['Special_Info'] = Phys['Special_Info'].str.lower()
Phys['Name'] = Phys['Name'].str.lower()
Phys['Special_Info'] = Phys['Special_Info'].str.replace(' required', '', case=False)

columns_to_process = ['Field_Type', 'Name', 'Special_Info']

for col in columns_to_process:
    Phys[col] = Phys[col].astype(str).str.strip()
    
Phys['Name_Cap'] = Phys['Name'].str.upper()

split_special_info = Phys['Special_Info'].str.split(',', expand=True)
split_special_info = split_special_info.applymap(lambda x: x.strip() if x is not None else None)

Phys = pd.concat([Phys, split_special_info], axis=1)

Phys = Phys.replace({None: np.nan})

for i in range(0, 8):
    Phys[f'new_column{i}'] = Phys.apply(lambda row: str(f'cond({row["Name"]} ==  {Phys.columns[i+4]}, "{row[i]}", '), axis=1).astype(str)

    Phys['new_combined_column'] = ""

for i in range(0, 8):
    Phys['new_combined_column'] += Phys.apply(lambda row: row[f"new_column{i}"] if 'nan' not in str(row[f"new_column{i}"]).lower() else '', axis=1)
    
Phys["generate"] = Phys.apply(lambda row: f'generate {row["Name_Cap"]} = {row["new_combined_column"]}""))', axis=1)

Phys["generate"] = Phys["generate"].apply(lambda x: x + ")" if "2," in str(x) else x)
Phys["generate"] = Phys["generate"].apply(lambda x: x + ")" if "3," in str(x) else x)
Phys["generate"] = Phys["generate"].apply(lambda x: x + ")" if "4," in str(x) else x)
Phys["generate"] = Phys["generate"].apply(lambda x: x + ")" if "5," in str(x) else x)
Phys["generate"] = Phys["generate"].apply(lambda x: x + ")" if "6," in str(x) else x)
Phys["generate"] = Phys["generate"].apply(lambda x: x + ")" if "7," in str(x) else x)
Phys["generate"] = Phys["generate"].apply(lambda x: x + ")" if "8," in str(x) else x)
Phys["generate"] = Phys["generate"].apply(lambda x: x + ")" if "9," in str(x) else x)
Phys["generate"] = Phys["generate"].apply(lambda x: x + ")" if "10," in str(x) else x)
Phys["generate"] = Phys["generate"].apply(lambda x: x + ")" if "11," in str(x) else x)
Phys["generate"] = Phys["generate"].apply(lambda x: x + ")" if "12," in str(x) else x)
Phys["generate"] = Phys["generate"].apply(lambda x: x + ")" if "13," in str(x) else x)

Phys["drop"] = Phys.apply(lambda row: f'drop {row["Name"]}', axis=1)
Phys["full_instruction"] = Phys.apply(lambda row: f'{row["generate"]}\n\n{row["drop"]}', axis=1)

Phys_file = '../CADAS/recode_files/Phys_to_numeric.txt'
with open(Phys_file, 'w') as f:
    for code_line in Phys['generate']:
        f.write(f"{code_line}\n\n")

Phys.head()
# Out:
#   Field_Type  Name                                       Special_Info  \
# 0     Option  p2_1                                              no,si
# 1     Option    p6  mirada hacia arriba normal,mirada hacia arriba...
# 2     Option  p7_1  1-4 golpes,5 golpes,6-9 golpes,10+ golpes,no i...
# 3     Option  p7_2  no hace trompa (protruye los labios),trompa pr...
# 4     Option  p7_3  no hay contracción facial,reflejo de contracci...
#
#   Name_Cap                                     0  \
# 0     P2_1                                    no
# 1       P6            mirada hacia arriba normal
# 2     P7_1                            1-4 golpes
# 3     P7_2  no hace trompa (protruye los labios)
# 4     P7_3             no hay contracción facial
#
#                                         1  \
# 0                                      si
# 1            mirada hacia arriba limitada
# 2                                5 golpes
# 3                         trompa presente
# ...

# %%
Household = (
    pd.read_excel("../CADAS/CADAS_DD_V4.xlsx", engine='openpyxl', sheet_name="Household")  # replace with your file path
    .loc[lambda df: df['Field_Type'] == 'Option', ['Field_Type', 'Name', 'Special_Info']]
    .reset_index(drop=True)
)

Household['Special_Info'] = Household['Special_Info'].str.lower()
Household['Name'] = Household['Name'].str.lower()
Household['Special_Info'] = Household['Special_Info'].str.replace(' required', '', case=False)

columns_to_process = ['Field_Type', 'Name', 'Special_Info']

for col in columns_to_process:
    Household[col] = Household[col].astype(str).str.strip()
    
Household['Name_Cap'] = Household['Name'].str.upper()

split_special_info = Household['Special_Info'].str.split(',', expand=True)
split_special_info = split_special_info.applymap(lambda x: x.strip() if x is not None else None)

Household = pd.concat([Household, split_special_info], axis=1)

Household = Household.replace({None: np.nan})

for i in range(0, 8):
    Household[f'new_column{i}'] = Household.apply(lambda row: str(f'cond({row["Name"]} ==  {Household.columns[i+4]}, "{row[i]}", '), axis=1).astype(str)

    Household['new_combined_column'] = ""

for i in range(0, 8):
    Household['new_combined_column'] += Household.apply(lambda row: row[f"new_column{i}"] if 'nan' not in str(row[f"new_column{i}"]).lower() else '', axis=1)
    
Household["generate"] = Household.apply(lambda row: f'generate {row["Name_Cap"]} = {row["new_combined_column"]}""))', axis=1)

Household["generate"] = Household["generate"].apply(lambda x: x + ")" if "2," in str(x) else x)
Household["generate"] = Household["generate"].apply(lambda x: x + ")" if "3," in str(x) else x)
Household["generate"] = Household["generate"].apply(lambda x: x + ")" if "4," in str(x) else x)
Household["generate"] = Household["generate"].apply(lambda x: x + ")" if "5," in str(x) else x)
Household["generate"] = Household["generate"].apply(lambda x: x + ")" if "6," in str(x) else x)
Household["generate"] = Household["generate"].apply(lambda x: x + ")" if "7," in str(x) else x)
Household["generate"] = Household["generate"].apply(lambda x: x + ")" if "8," in str(x) else x)
Household["generate"] = Household["generate"].apply(lambda x: x + ")" if "9," in str(x) else x)
Household["generate"] = Household["generate"].apply(lambda x: x + ")" if "10," in str(x) else x)
Household["generate"] = Household["generate"].apply(lambda x: x + ")" if "11," in str(x) else x)
Household["generate"] = Household["generate"].apply(lambda x: x + ")" if "12," in str(x) else x)
Household["generate"] = Household["generate"].apply(lambda x: x + ")" if "13," in str(x) else x)

Household["drop"] = Household.apply(lambda row: f'drop {row["Name"]}', axis=1)
Household["full_instruction"] = Household.apply(lambda row: f'{row["generate"]}\n\n{row["drop"]}', axis=1)


Household_file = '../CADAS/recode_files/Household_to_numeric.txt'
with open(Household_file, 'w') as f:
    for code_line in Household['generate']:
        f.write(f"{code_line}\n\n")

Household.head()
# Out:
#   Field_Type      Name                  Special_Info  Name_Cap            0  \
# 0     Option     h_3_1  propietario ,alquilada ,otro     H_3_1  propietario
# 1     Option  h_3_3a_p     si,no,no responde,no sabe  H_3_3A_P           si
# 2     Option  h_3_3a_d     si,no,no responde,no sabe  H_3_3A_D           si
# 3     Option  h_3_3a_c     si,no,no responde,no sabe  H_3_3A_C           si
# 4     Option  h_3_3b_p     si,no,no responde,no sabe  H_3_3B_P           si
#
#            1            2        3    4    5  ...  \
# 0  alquilada         otro      NaN  NaN  NaN  ...
# 1         no  no responde  no sabe  NaN  NaN  ...
# 2         no  no responde  no sabe  NaN  NaN  ...
# 3         no  no responde  no sabe  NaN  NaN  ...
# 4         no  no responde  no sabe  NaN  NaN  ...
#
#                        new_column1                           new_column2  \
# 0  cond(h_3_1 ==  1, "alquilada",             cond(h_3_1 ==  2, "otro",
# ...
