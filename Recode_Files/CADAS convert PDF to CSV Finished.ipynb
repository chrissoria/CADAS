# %%
pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in d:\python\anaconda\lib\site-packages (3.0.1)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in d:\python\anaconda\lib\site-packages (from PyPDF2) (4.7.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# The box of code under this is the NEW code.

# %%
#THIS IS THE NEW CODE, IT HAS FIXED THE PERSONID AND SEARCHES FOR EACH TEST TO MAKE SURE IT IS PRESENT
#DO NOT FORGET TO REPLACE THE FOLDER PATH AT THE TOP WITH YOUR FOLDER CONTAINING THE PDFS
#DO NOT FORGET TO REPLACE THE DESTINATION CSV AT THE VERY BOTTOM WITH ITS PATH
import re
from PyPDF2 import PdfReader
import os,glob
folder_path = r"/Users/chrissoria/Documents/Research/Read_PDF/Cluster_06_Fecha_2_8_23/PDFs"
for filename in glob.glob(os.path.join(folder_path, '*.pdf')):
    with open(filename, 'r') as f:
        reader = PdfReader(filename)
        finaltext = "start"
        for i in range(len(reader.pages)):
            page = reader.pages[i]
            finaltext = finaltext + "\n" + page.extract_text()
        ID_match = re.search(r'(CLUSTER.{0,12})', finaltext)
        if ID_match:
            ParticID = ID_match.group(1)
            ParticID = ParticID.replace("CLUSTER", "")
            ParticID = ParticID.replace("-", ", ")
            cluster = ParticID.split(",")[0]
            houseid = ParticID.split(",")[1]
            personid = ParticID.split(",")[2]
            personid = personid.strip()
        else:
            cluster = ","
            houseid = ","
            personid = ","
        if personid[0:1] != "0":
            personid = personid[0:1]
        else:
            personid = personid[0:2]
        age_match = re.search(r'(.{0,5}Años)', finaltext)
        age_sex = age_match.group(1)
        age_sex = age_sex.replace("Años", "")
        age_sex = age_sex[:2] + ", " + age_sex[2:]
        globulos_blancos = re.search(r'(Blancos...{0,31})', finaltext)
        if globulos_blancos:
            data1 = globulos_blancos[0]
            data1 = data1.replace("Blancos............K/uL........", "")
        else:
            data1 = "."
        globulos_rojos = re.search(r'(Rojos...{0,31})', finaltext)
        if globulos_rojos:
            data2 = globulos_rojos[0]
            data2 = data2.replace("Rojos..............M/uL........", "")
        else:
            data2 = "."
        hemoglobina = re.search(r'(Hemoglobina...{0,35})', finaltext)
        if hemoglobina:
            data3 = hemoglobina[0]
            data3 = data3.replace("Hemoglobina.................g/dL........", "")
        else:
            data3 = "."
        hematocrito = re.search(r'(Hematócrito...{0,35})', finaltext)
        if hematocrito:
            data4 = hematocrito[0]
            data4 = data4.replace("Hematócrito.................%...........", "")
        else:
            data4 = "." 
        VCM = re.search(r'(VCM...{0,43})', finaltext)
        if VCM:
            data5 = VCM[0]
            data5 = data5.replace("VCM.........................fL..........", "")
        else:
            data5 = "."
        HCM = re.search(r'(\nHCM...{0,43})', finaltext)
        if HCM:
            data6 = HCM[0]
            data6 = data6.replace("\nHCM.........................pg..........", "")
        else:
            data6 = "."
        CHCM = re.search(r'(CHCM...{0,43})', finaltext)
        if CHCM:
            data7 = CHCM[0]
            data7 = data7.replace("CHCM........................g/dL........", "")
        else:
            data7 = "."
        RDW = re.search(r'(RDW...{0,43})', finaltext)
        if RDW:
            data8 = RDW[0]
            data8 = data8.replace("RDW.........................%...........", "")
        else:
            data8 = "."
        plaquetas = re.search(r'(Plaquetas...{37})', finaltext)
        if plaquetas:
            data9 = plaquetas[0]
            data9 = data9.replace("Plaquetas...................K/uL........", "")
        else:
            data9 = "."
        VPM = re.search(r'(VPM...{0,43})', finaltext)        
        if VPM:
            data10 = VPM[0]
            data10 = data10.replace("VPM.........................fL..........", "")
        else:
            data10 = "."
        PDW = re.search(r'(PDW...{0,43})', finaltext)
        if PDW:
            data11 = PDW[0]
            data11 = data11.replace("PDW.........................GSD.........", "")
        else:
            data11 = "."
        neutrofilos = re.search(r'(Neutrofilos...{0,35})', finaltext)
        if neutrofilos:
            data12 = neutrofilos[0]
            data12 = data12.replace("Neutrofilos.................K/uL........", "")
        else:
            data12 = "."
        neutrofilosP = re.search(r'(Neutrofilos %...{0,33})', finaltext)
        if neutrofilosP:
            data13 = neutrofilosP[0]
            data13 = data13.replace("Neutrofilos %...............%...........", "")
        else:
            data13 = "."
        linfocitos = re.search(r'(Linfocitos...{0,36})', finaltext)
        if linfocitos:
            data14 = linfocitos[0]
            data14 = data14.replace("Linfocitos..................K/uL........", "")
        else:
            data14 = "."
        linfocitosP = re.search(r'(Linfocitos %...{0,34})', finaltext)
        if linfocitosP:
            data15 = linfocitosP[0]
            data15 = data15.replace("Linfocitos %................%...........", "")
        else:
            data15 = "."
        monocitos = re.search(r'(Monocitos...{0,37})', finaltext)
        if monocitos:
            data16 = monocitos[0]
            data16 = data16.replace("Monocitos...................K/uL........", "")
        else:
            data16 = "."
        monocitosP = re.search(r'(Monocitos %...{0,35})', finaltext)
        if monocitosP:
            data17 = monocitosP[0]
            data17 = data17.replace("Monocitos %.................%...........", "")
        else:
            data17 = "."
        eosinofilos = re.search(r'(Eosinófilos...{0,35})', finaltext)
        if eosinofilos:
            data18 = eosinofilos[0]
            data18 = data18.replace("Eosinófilos.................K/uL........", "")
        else:
            data18 = "."
        eosinofilosP = re.search(r'(Eosinofilos %...{0,33})', finaltext)
        if eosinofilosP:
            data19 = eosinofilosP[0]
            data19 = data19.replace("Eosinofilos %...............%...........", "")
        else:
            data19 = "."
        basofilos = re.search(r'(Basófilos...{0,37})', finaltext)
        if basofilos:
            data20 = basofilos[0]
            data20 = data20.replace("Basófilos...................K/uL........", "")
        else:
            data20 = "."
        basofilosP = re.search(r'(Basófilos %...{0,35})', finaltext)
        if basofilosP:
            data21 = basofilosP[0]
            data21 = data21.replace("Basófilos %.................%...........", "")
        else:
            data21 = "."
        hba1c = re.search(r'(HbA1c...{0,41})', finaltext)
        if hba1c:
            data22 = hba1c[0]
            data22 = data22.replace("HbA1c.......................%...........", "")
        else:
            data22 = "."
        alldata = "\n" + cluster + "," + houseid + "," + personid + "," + age_sex + "," + data1 + "," + data2 + "," + data3 + "," + data4 + "," + data5 + "," + data6 + "," + data7 + "," + data8 + "," + data9 + "," + data10 + "," + data11 + "," + data12 + "," + data13 + "," + data14 + "," + data15 + "," + data16 + "," + data17 + "," + data18 + "," + data19 + "," + data20 + "," + data21 + "," + data22
        with open("/Users/chrissoria/Documents/Research/Read_PDF/PythonCSVtest.csv", 'a') as out:
            out.write(alldata)

# %%
#THIS IS THE NEW CODE, IT HAS FIXED THE PERSONID AND SEARCHES FOR EACH TEST TO MAKE SURE IT IS PRESENT
#DO NOT FORGET TO REPLACE THE FOLDER PATH AT THE TOP WITH YOUR FOLDER CONTAINING THE PDFS
#DO NOT FORGET TO REPLACE THE DESTINATION CSV AT THE VERY BOTTOM WITH ITS PATH
import re
from PyPDF2 import PdfReader
import os,glob
folder_path = r"/Users/chrissoria/Documents/Research/Read_PDF/Cluster_02"
for filename in glob.glob(os.path.join(folder_path, '*.pdf')):
    with open(filename, 'r') as f:
        reader = PdfReader(filename)
        finaltext = "start"
        for i in range(len(reader.pages)):
            page = reader.pages[i]
            finaltext = finaltext + "\n" + page.extract_text()
        ID_match = re.search(r'(CLUSTER.{0,12})', finaltext)
        if ID_match:
            ParticID = ID_match.group(1)
            ParticID = ParticID.replace("CLUSTER", "")
            ParticID = ParticID.replace("-", ", ")
            cluster = ParticID.split(",")[0]
            houseid = ParticID.split(",")[1]
            personid = ParticID.split(",")[2]
            personid = personid.strip()
        else:
            cluster = ","
            houseid = ","
            personid = ","
        if personid[0:1] != "0":
            personid = personid[0:1]
        else:
            personid = personid[0:2]
        age_match = re.search(r'(.{0,5}Años)', finaltext)
        age_sex = age_match.group(1)
        age_sex = age_sex.replace("Años", "")
        age_sex = age_sex[:2] + ", " + age_sex[2:]
        globulos_blancos = re.search(r'(Blancos...{0,31})', finaltext)
        if globulos_blancos:
            data1 = globulos_blancos[0]
            data1 = data1.replace("Blancos............K/uL........", "")
        else:
            data1 = "."
        globulos_rojos = re.search(r'(Rojos...{0,31})', finaltext)
        if globulos_rojos:
            data2 = globulos_rojos[0]
            data2 = data2.replace("Rojos..............M/uL........", "")
        else:
            data2 = "."
        hemoglobina = re.search(r'(Hemoglobina...{0,35})', finaltext)
        if hemoglobina:
            data3 = hemoglobina[0]
            data3 = data3.replace("Hemoglobina.................g/dL........", "")
        else:
            data3 = "."
        hematocrito = re.search(r'(Hematócrito...{0,35})', finaltext)
        if hematocrito:
            data4 = hematocrito[0]
            data4 = data4.replace("Hematócrito.................%...........", "")
        else:
            data4 = "." 
        VCM = re.search(r'(VCM...{0,43})', finaltext)
        if VCM:
            data5 = VCM[0]
            data5 = data5.replace("VCM.........................fL..........", "")
        else:
            data5 = "."
        HCM = re.search(r'(\nHCM...{0,43})', finaltext)
        if HCM:
            data6 = HCM[0]
            data6 = data6.replace("\nHCM.........................pg..........", "")
        else:
            data6 = "."
        CHCM = re.search(r'(CHCM...{0,43})', finaltext)
        if CHCM:
            data7 = CHCM[0]
            data7 = data7.replace("CHCM........................g/dL........", "")
        else:
            data7 = "."
        RDW = re.search(r'(RDW...{0,43})', finaltext)
        if RDW:
            data8 = RDW[0]
            data8 = data8.replace("RDW.........................%...........", "")
        else:
            data8 = "."
        plaquetas = re.search(r'(Plaquetas...{37})', finaltext)
        if plaquetas:
            data9 = plaquetas[0]
            data9 = data9.replace("Plaquetas...................K/uL........", "")
        else:
            data9 = "."
        VPM = re.search(r'(VPM...{0,43})', finaltext)        
        if VPM:
            data10 = VPM[0]
            data10 = data10.replace("VPM.........................fL..........", "")
        else:
            data10 = "."
        PDW = re.search(r'(PDW...{0,43})', finaltext)
        if PDW:
            data11 = PDW[0]
            data11 = data11.replace("PDW.........................GSD.........", "")
        else:
            data11 = "."
        neutrofilos = re.search(r'(Neutrofilos...{0,35})', finaltext)
        if neutrofilos:
            data12 = neutrofilos[0]
            data12 = data12.replace("Neutrofilos.................K/uL........", "")
        else:
            data12 = "."
        neutrofilosP = re.search(r'(Neutrofilos %...{0,33})', finaltext)
        if neutrofilosP:
            data13 = neutrofilosP[0]
            data13 = data13.replace("Neutrofilos %...............%...........", "")
        else:
            data13 = "."
        linfocitos = re.search(r'(Linfocitos...{0,36})', finaltext)
        if linfocitos:
            data14 = linfocitos[0]
            data14 = data14.replace("Linfocitos..................K/uL........", "")
        else:
            data14 = "."
        linfocitosP = re.search(r'(Linfocitos %...{0,34})', finaltext)
        if linfocitosP:
            data15 = linfocitosP[0]
            data15 = data15.replace("Linfocitos %................%...........", "")
        else:
            data15 = "."
        monocitos = re.search(r'(Monocitos...{0,37})', finaltext)
        if monocitos:
            data16 = monocitos[0]
            data16 = data16.replace("Monocitos...................K/uL........", "")
        else:
            data16 = "."
        monocitosP = re.search(r'(Monocitos %...{0,35})', finaltext)
        if monocitosP:
            data17 = monocitosP[0]
            data17 = data17.replace("Monocitos %.................%...........", "")
        else:
            data17 = "."
        eosinofilos = re.search(r'(Eosinófilos...{0,35})', finaltext)
        if eosinofilos:
            data18 = eosinofilos[0]
            data18 = data18.replace("Eosinófilos.................K/uL........", "")
        else:
            data18 = "."
        eosinofilosP = re.search(r'(Eosinofilos %...{0,33})', finaltext)
        if eosinofilosP:
            data19 = eosinofilosP[0]
            data19 = data19.replace("Eosinofilos %...............%...........", "")
        else:
            data19 = "."
        basofilos = re.search(r'(Basófilos...{0,37})', finaltext)
        if basofilos:
            data20 = basofilos[0]
            data20 = data20.replace("Basófilos...................K/uL........", "")
        else:
            data20 = "."
        basofilosP = re.search(r'(Basófilos %...{0,35})', finaltext)
        if basofilosP:
            data21 = basofilosP[0]
            data21 = data21.replace("Basófilos %.................%...........", "")
        else:
            data21 = "."
        hba1c = re.search(r'(HbA1c...{0,41})', finaltext)
        if hba1c:
            data22 = hba1c[0]
            data22 = data22.replace("HbA1c.......................%...........", "")
        else:
            data22 = "."
        alldata = "\n" + cluster + "," + houseid + "," + personid + "," + age_sex + "," + data1 + "," + data2 + "," + data3 + "," + data4 + "," + data5 + "," + data6 + "," + data7 + "," + data8 + "," + data9 + "," + data10 + "," + data11 + "," + data12 + "," + data13 + "," + data14 + "," + data15 + "," + data16 + "," + data17 + "," + data18 + "," + data19 + "," + data20 + "," + data21 + "," + data22
        with open("/Users/chrissoria/Documents/Research/Read_PDF/Cluster_02.csv", 'a') as out:
            out.write(alldata)

# %%
#THIS IS THE NEW CODE, IT HAS FIXED THE PERSONID AND SEARCHES FOR EACH TEST TO MAKE SURE IT IS PRESENT
#DO NOT FORGET TO REPLACE THE FOLDER PATH AT THE TOP WITH YOUR FOLDER CONTAINING THE PDFS
#DO NOT FORGET TO REPLACE THE DESTINATION CSV AT THE VERY BOTTOM WITH ITS PATH
import re
from PyPDF2 import PdfReader
import os,glob
folder_path = r"/Users/chrissoria/Documents/Research/Read_PDF/Cluster_08"
for filename in glob.glob(os.path.join(folder_path, '*.pdf')):
    with open(filename, 'r') as f:
        reader = PdfReader(filename)
        finaltext = "start"
        for i in range(len(reader.pages)):
            page = reader.pages[i]
            finaltext = finaltext + "\n" + page.extract_text()
        ID_match = re.search(r'(CLUSTER.{0,12})', finaltext)
        if ID_match:
            ParticID = ID_match.group(1)
            ParticID = ParticID.replace("CLUSTER", "")
            ParticID = ParticID.replace("-", ", ")
            cluster = ParticID.split(",")[0]
            houseid = ParticID.split(",")[1]
            personid = ParticID.split(",")[2]
            personid = personid.strip()
        else:
            cluster = ","
            houseid = ","
            personid = ","
        if personid[0:1] != "0":
            personid = personid[0:1]
        else:
            personid = personid[0:2]
        age_match = re.search(r'(.{0,5}Años)', finaltext)
        age_sex = age_match.group(1)
        age_sex = age_sex.replace("Años", "")
        age_sex = age_sex[:2] + ", " + age_sex[2:]
        globulos_blancos = re.search(r'(Blancos...{0,31})', finaltext)
        if globulos_blancos:
            data1 = globulos_blancos[0]
            data1 = data1.replace("Blancos............K/uL........", "")
        else:
            data1 = "."
        globulos_rojos = re.search(r'(Rojos...{0,31})', finaltext)
        if globulos_rojos:
            data2 = globulos_rojos[0]
            data2 = data2.replace("Rojos..............M/uL........", "")
        else:
            data2 = "."
        hemoglobina = re.search(r'(Hemoglobina...{0,35})', finaltext)
        if hemoglobina:
            data3 = hemoglobina[0]
            data3 = data3.replace("Hemoglobina.................g/dL........", "")
        else:
            data3 = "."
        hematocrito = re.search(r'(Hematócrito...{0,35})', finaltext)
        if hematocrito:
            data4 = hematocrito[0]
            data4 = data4.replace("Hematócrito.................%...........", "")
        else:
            data4 = "." 
        VCM = re.search(r'(VCM...{0,43})', finaltext)
        if VCM:
            data5 = VCM[0]
            data5 = data5.replace("VCM.........................fL..........", "")
        else:
            data5 = "."
        HCM = re.search(r'(\nHCM...{0,43})', finaltext)
        if HCM:
            data6 = HCM[0]
            data6 = data6.replace("\nHCM.........................pg..........", "")
        else:
            data6 = "."
        CHCM = re.search(r'(CHCM...{0,43})', finaltext)
        if CHCM:
            data7 = CHCM[0]
            data7 = data7.replace("CHCM........................g/dL........", "")
        else:
            data7 = "."
        RDW = re.search(r'(RDW...{0,43})', finaltext)
        if RDW:
            data8 = RDW[0]
            data8 = data8.replace("RDW.........................%...........", "")
        else:
            data8 = "."
        plaquetas = re.search(r'(Plaquetas...{37})', finaltext)
        if plaquetas:
            data9 = plaquetas[0]
            data9 = data9.replace("Plaquetas...................K/uL........", "")
        else:
            data9 = "."
        VPM = re.search(r'(VPM...{0,43})', finaltext)        
        if VPM:
            data10 = VPM[0]
            data10 = data10.replace("VPM.........................fL..........", "")
        else:
            data10 = "."
        PDW = re.search(r'(PDW...{0,43})', finaltext)
        if PDW:
            data11 = PDW[0]
            data11 = data11.replace("PDW.........................GSD.........", "")
        else:
            data11 = "."
        neutrofilos = re.search(r'(Neutrofilos...{0,35})', finaltext)
        if neutrofilos:
            data12 = neutrofilos[0]
            data12 = data12.replace("Neutrofilos.................K/uL........", "")
        else:
            data12 = "."
        neutrofilosP = re.search(r'(Neutrofilos %...{0,33})', finaltext)
        if neutrofilosP:
            data13 = neutrofilosP[0]
            data13 = data13.replace("Neutrofilos %...............%...........", "")
        else:
            data13 = "."
        linfocitos = re.search(r'(Linfocitos...{0,36})', finaltext)
        if linfocitos:
            data14 = linfocitos[0]
            data14 = data14.replace("Linfocitos..................K/uL........", "")
        else:
            data14 = "."
        linfocitosP = re.search(r'(Linfocitos %...{0,34})', finaltext)
        if linfocitosP:
            data15 = linfocitosP[0]
            data15 = data15.replace("Linfocitos %................%...........", "")
        else:
            data15 = "."
        monocitos = re.search(r'(Monocitos...{0,37})', finaltext)
        if monocitos:
            data16 = monocitos[0]
            data16 = data16.replace("Monocitos...................K/uL........", "")
        else:
            data16 = "."
        monocitosP = re.search(r'(Monocitos %...{0,35})', finaltext)
        if monocitosP:
            data17 = monocitosP[0]
            data17 = data17.replace("Monocitos %.................%...........", "")
        else:
            data17 = "."
        eosinofilos = re.search(r'(Eosinófilos...{0,35})', finaltext)
        if eosinofilos:
            data18 = eosinofilos[0]
            data18 = data18.replace("Eosinófilos.................K/uL........", "")
        else:
            data18 = "."
        eosinofilosP = re.search(r'(Eosinofilos %...{0,33})', finaltext)
        if eosinofilosP:
            data19 = eosinofilosP[0]
            data19 = data19.replace("Eosinofilos %...............%...........", "")
        else:
            data19 = "."
        basofilos = re.search(r'(Basófilos...{0,37})', finaltext)
        if basofilos:
            data20 = basofilos[0]
            data20 = data20.replace("Basófilos...................K/uL........", "")
        else:
            data20 = "."
        basofilosP = re.search(r'(Basófilos %...{0,35})', finaltext)
        if basofilosP:
            data21 = basofilosP[0]
            data21 = data21.replace("Basófilos %.................%...........", "")
        else:
            data21 = "."
        hba1c = re.search(r'(HbA1c...{0,41})', finaltext)
        if hba1c:
            data22 = hba1c[0]
            data22 = data22.replace("HbA1c.......................%...........", "")
        else:
            data22 = "."
        alldata = "\n" + cluster + "," + houseid + "," + personid + "," + age_sex + "," + data1 + "," + data2 + "," + data3 + "," + data4 + "," + data5 + "," + data6 + "," + data7 + "," + data8 + "," + data9 + "," + data10 + "," + data11 + "," + data12 + "," + data13 + "," + data14 + "," + data15 + "," + data16 + "," + data17 + "," + data18 + "," + data19 + "," + data20 + "," + data21 + "," + data22
        with open("/Users/chrissoria/Documents/Research/Read_PDF/Cluster_08.csv", 'a') as out:
            out.write(alldata)

# %% [markdown]
# The box of code under this is the OLD code.

# %%
import re
from PyPDF2 import PdfReader
import os,glob
folder_path = r"C:\Users\Ty\Downloads\Cluster 08 (5)"
for filename in glob.glob(os.path.join(folder_path, '*.pdf')):
    with open(filename, 'r') as f:
        reader = PdfReader(filename)
        finaltext = "start"
        for i in range(len(reader.pages)):
            page = reader.pages[i]
            finaltext = finaltext + "\n" + page.extract_text()
        finaltext = finaltext.replace("... ", "zyxw")
        ID_match = re.search(r'(CLUSTER.{0,10})', finaltext)
        if ID_match:
            ParticID = ID_match.group(1)
            ParticID = ParticID.replace("CLUSTER", "")
            ParticID = ParticID.replace("-", ", ")
        age_match = re.search(r'(.{0,5}Años)', finaltext)
        age_sex = age_match.group(1)
        age_sex = age_sex.replace("Años", "")
        age_sex = age_sex[:2] + ", " + age_sex[2:]
        alldata = re.findall(r'(zyxw.{0,8})', finaltext)
        alldata = ",".join(str(element) for element in alldata)
        alldata = "\n" + ParticID + "," + age_sex + "," + alldata.replace("zyxw", "")
        with open("C:\\Users\\Ty\\Desktop\\PythonCSVtest.csv", 'a') as out:
            out.write(alldata)
