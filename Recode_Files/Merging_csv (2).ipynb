# %%
import os,glob
import pandas as pd
import numpy as np
import re

# %% [markdown]
# change country between: PR, DR, CU

# %%
user = "Ty"
country = "DR"

# %%
CU_directory = r"/Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/cuba"
DR_directory = r"/Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Rep Dom"
PR_drectory = r"/Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Puerto_Rico"

if user == "Chris":
    if country == "DR":
        current_directory = DR_directory
        path1 = DR_directory+"/All_CSVs" #where all CSVs are located
        path2 = DR_directory+"/Sync Files/02.12.23/CSV" #change to show latest upload
    elif country == "CU":
        current_directory = CU_directory
        path1 = CU_directory+"/All_CSVs" #where we merge all cumulative CSV files into one file
        path2 = CU_directory+"/10_17_23/CSV" #where we check to see that the latest batch of data includes all files it should
    elif country == "PR":
        current_directory = PR_directory
        path1 = PR_directory+"/All_CSVs"
        path2 = PR_directory+"/11_13_23"
elif user == "Ty":
    if country == "DR":
        current_directory = r"C:\Users\Ty\Desktop\newestCSVs\DR"
        path1 = r"G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs" #where all CSVs are located
        path2 = r"G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\Sync Files\02.12.23\CSV" #change to show latest upload
        imagepath = r"G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_Image_Files"
        audiopath = r"G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_Audio_Files"
    elif country == "CU":
        current_directory = r"C:\Users\Ty\Desktop\newestCSVs\CUBA"
        path1 = r"G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Cuba\All_CSVs" #where we merge all cumulative CSV files into one file
        path2 = r"G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Cuba\10_17_23\CSV" #where we check to see that the latest batch of data includes all files it should
    elif country == "PR":
        current_directory = r"C:\Users\Ty\Desktop\newestCSVs\PR"
        path1 = r"G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Puerto_Rico\All_CSVs"
        path2 = r"G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Puerto_Rico\Sync files\11_13_23"
else:
    print("Unknown user. Cannot set directory.")
    current_directory = None

if current_directory:
    os.chdir(current_directory)
    file_list = os.listdir(current_directory)
    print(f"Changed directory to: {current_directory}")
    print(path1)
    print(path2)
    print(file_list)
# Out:
# Changed directory to: C:\Users\Ty\Desktop\newestCSVs\DR
# G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs
# G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\Sync Files\02.12.23\CSV
# ['CSV_Merged', 'Received_Files_Checklist.xlsx']

# %% [markdown]
# Received files document

# %%
# Get the list of all files in the latest file upload
dir_list1 = os.listdir(path2) #(this should be changed to a folder with all the epi7 files from the latest upload)

# To see which files I received from the data manager (for now not doing anything with this)
newdir_list1 = [x.replace(".epi7", "") for x in dir_list1]

# To see which files I was able to process with Epi Info tool
dir_list2 = os.listdir(path2)
newdir_list2 = [x.replace(".csv", "") for x in dir_list2]

def remove_common(a, b):
    for i in a[:]:
        if i in b:
            a.remove(i)
            b.remove(i)

    print("list1 : ", a)
    print("list2 : ", b)

remove_common(newdir_list1, newdir_list2)

words_to_filter = ["Neighborhood", "Door", "_informationdoor_", "_informationdoorparticipants", "Listas", "_mainhousehold", "_participants", "_rosterhousehold", "_nonresidentchildren", "Cognitiva", "_cognitive", "Cognitive_Scoring", "Examen_Físico", "_physical_exam","Familiar", "_household", "Informante", "_informant", "_sociodemographic", "Sociodemográfica", "Sangre"]

# breaking the longer list into smaller lists
filtered_lists = {word: [] for word in words_to_filter}

for text in newdir_list2:
    for word in words_to_filter:
        if word in text:
            filtered_lists[word].append(text)

# change this number depending on how many tablets worth of information you're receiving
for word, filtered_list in filtered_lists.items():
    while len(filtered_list) < 8:
        filtered_list.append("Falta")

Received_Files = pd.DataFrame()

for word, filtered_list in filtered_lists.items():
    Received_Files[word] = pd.Series(filtered_list)

Received_Files.to_excel(path2+ 'Received_Files_Checklist.xlsx', index=False)

Received_Files
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-942ceb086e96> in <module>
#       1 # Get the list of all files in the latest file upload
# ----> 2 dir_list1 = os.listdir(path2) #(this should be changed to a folder with all the epi7 files from the latest upload)
#       3
#       4 # To see which files I received from the data manager (for now not doing anything with this)
#       5 newdir_list1 = [x.replace(".epi7", "") for x in dir_list1]
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'G:\\.shortcut-targets-by-id\\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\\CADAS data upload\\Rep Dom\\Sync Files\\02.12.23\\CSV'

# %%
if user == "Chris":
    if country == "CU":
        pattern = "/Users/chrissoria/Google Drive/Other Computers/My Laptop \(1\)/documents/cadas/data/CADAS data upload/cuba/All_CSVs/"
    elif country == "DR":
        pattern = "/Users/chrissoria/Google Drive/Other Computers/My Laptop \(1\)/documents/cadas/data/CADAS data upload/Rep \Dom/All_CSVs/"
    elif country == "PR":
        pattern = "/Users/chrissoria/Google Drive/Other Computers/My Laptop \(1\)/documents/cadas/data/CADAS data upload/Puerto_Rico/All_CSVs/"
elif user == "Ty":
    if country == "CU":
        pattern = path1
    elif country == "DR":
        pattern = path1
    elif country == "PR":
        pattern = path1
else:
    print("Unknown user. Cannot set directory.")
    current_directory = None

folder_path = path1 #goes through this whole folder

####COGNITIVE CHILD#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*_cognitive*.csv')):
    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    if user == "Chris":
        pattern_to_remove = pattern + "_cognitive_"
        df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
        df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
        df['filename'] = df['filename'].astype(int)
        dfs.append(df)
    elif user == "Ty":
        pattern_to_remove = path1+r"\_cognitive_"
        for x in range(len(df['filename'])):
            df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
            df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
            df['filename'][x] = int(df['filename'][x])
            dfs.append(df)
    
cog_child = pd.concat(dfs, ignore_index=True)
cog_child = cog_child.sort_values(by='filename', ascending=False)
cog_child = cog_child.drop(columns=['filename'])
cog_child = cog_child.drop_duplicates(subset='GlobalRecordId', keep='first')
pattern_to_remove = r'=HYPERLINK\("media\\([^"]+)",\"<CLICK HERE>"\)'
cog_child = cog_child.replace(pattern_to_remove, r'\1', regex=True)

imagenames = os.listdir(imagepath)
audionames = os.listdir(audiopath)

foundlist = []
piclist = cog_child['C_72_1_PIC'].tolist()
for i in range(len(cog_child['C_72_1_PIC'])):
    if piclist[i] in imagenames:
        foundlist = foundlist + ["found"]
    else:
        foundlist = foundlist + ["missing"]
cog_child['C_72_1_PIC_FOUND'] = foundlist

foundlist = []
piclist = cog_child['C_72_2_PIC'].tolist()
for i in range(len(cog_child['C_72_2_PIC'])):
    if piclist[i] in imagenames:
        foundlist = foundlist + ["found"]
    else:
        foundlist = foundlist + ["missing"]
cog_child['C_72_2_PIC_FOUND'] = foundlist

foundlist = []
piclist = cog_child['C_72_3_PIC'].tolist()
for i in range(len(cog_child['C_72_3_PIC'])):
    if piclist[i] in imagenames:
        foundlist = foundlist + ["found"]
    else:
        foundlist = foundlist + ["missing"]
cog_child['C_72_3_PIC_FOUND'] = foundlist

foundlist = []
piclist = cog_child['C_72_4_PIC'].tolist()
for i in range(len(cog_child['C_72_4_PIC'])):
    if piclist[i] in imagenames:
        foundlist = foundlist + ["found"]
    else:
        foundlist = foundlist + ["missing"]
cog_child['C_72_4_PIC_FOUND'] = foundlist

foundlist = []
piclist = cog_child['C_79_1_PIC'].tolist()
for i in range(len(cog_child['C_79_1_PIC'])):
    if piclist[i] in imagenames:
        foundlist = foundlist + ["found"]
    else:
        foundlist = foundlist + ["missing"]
cog_child['C_79_1_PIC_FOUND'] = foundlist

foundlist = []
piclist = cog_child['C_79_2_PIC'].tolist()
for i in range(len(cog_child['C_79_2_PIC'])):
    if piclist[i] in imagenames:
        foundlist = foundlist + ["found"]
    else:
        foundlist = foundlist + ["missing"]
cog_child['C_79_2_PIC_FOUND'] = foundlist

foundlist = []
piclist = cog_child['C_79_3_PIC'].tolist()
for i in range(len(cog_child['C_79_3_PIC'])):
    if piclist[i] in imagenames:
        foundlist = foundlist + ["found"]
    else:
        foundlist = foundlist + ["missing"]
cog_child['C_79_3_PIC_FOUND'] = foundlist

foundlist = []
piclist = cog_child['C_79_4_PIC'].tolist()
for i in range(len(cog_child['C_79_4_PIC'])):
    if piclist[i] in imagenames:
        foundlist = foundlist + ["found"]
    else:
        foundlist = foundlist + ["missing"]
cog_child['C_79_4_PIC_FOUND'] = foundlist

foundlist = []
piclist = cog_child['ANIM_PIC'].tolist()
for i in range(len(cog_child['ANIM_PIC'])):
    if piclist[i] in imagenames:
        foundlist = foundlist + ["found"]
    else:
        foundlist = foundlist + ["missing"]
cog_child['ANIM_PIC_FOUND'] = foundlist

foundlist = []
piclist = cog_child['SYMB_PIC'].tolist()
for i in range(len(cog_child['SYMB_PIC'])):
    if piclist[i] in imagenames:
        foundlist = foundlist + ["found"]
    else:
        foundlist = foundlist + ["missing"]
cog_child['SYMB_PIC_FOUND'] = foundlist

foundlist = []
piclist = cog_child['PENT_PIC'].tolist()
for i in range(len(cog_child['PENT_PIC'])):
    if piclist[i] in imagenames:
        foundlist = foundlist + ["found"]
    else:
        foundlist = foundlist + ["missing"]
cog_child['PENT_PIC_FOUND'] = foundlist

foundlist = []
piclist = cog_child['G_1_File'].tolist()
for i in range(len(cog_child['G_1_File'])):
    if piclist[i] in audionames:
        foundlist = foundlist + ["found"]
    else:
        foundlist = foundlist + ["missing"]
cog_child['G_1_File_FOUND'] = foundlist

foundlist = []
piclist = cog_child['G_2_File'].tolist()
for i in range(len(cog_child['G_2_File'])):
    if piclist[i] in audionames:
        foundlist = foundlist + ["found"]
    else:
        foundlist = foundlist + ["missing"]
cog_child['G_2_File_FOUND'] = foundlist

foundlist = []
piclist = cog_child['G_2_File2'].tolist()
for i in range(len(cog_child['G_2_File2'])):
    if piclist[i] in audionames:
        foundlist = foundlist + ["found"]
    else:
        foundlist = foundlist + ["missing"]
cog_child['G_2_File2_FOUND'] = foundlist

foundlist = []
piclist = cog_child['G_3_File'].tolist()
for i in range(len(cog_child['G_3_File'])):
    if piclist[i] in audionames:
        foundlist = foundlist + ["found"]
    else:
        foundlist = foundlist + ["missing"]
cog_child['G_3_File_FOUND'] = foundlist

foundlist = []
piclist = cog_child['G_3_File2'].tolist()
for i in range(len(cog_child['G_3_File2'])):
    if piclist[i] in audionames:
        foundlist = foundlist + ["found"]
    else:
        foundlist = foundlist + ["missing"]
cog_child['G_3_File2_FOUND'] = foundlist

cog_child.to_csv("CSV_Merged/Cog_Child.csv")

####COGNITIVE PARENT#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*Cognitiva*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    if user == "Chris":
        pattern_to_remove = pattern + 'Cognitiva_'
        df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
        df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
        df['filename'] = df['filename'].astype(int)
        dfs.append(df)
    elif user == "Ty":
        pattern_to_remove = path1+r"\Cognitiva_"
        for x in range(len(df['filename'])):
            df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
            df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
            df['filename'][x] = int(df['filename'][x])
            dfs.append(df)
    
cog_parent = pd.concat(dfs, ignore_index=True)
cog_parent = cog_parent.sort_values(by='filename', ascending=False)
cog_parent = cog_parent.drop(columns=['filename'])
cog_parent = cog_parent.drop_duplicates(subset='GlobalRecordId', keep='first')

cog_parent.to_csv("CSV_Merged/Cog_Parent.csv")

####COGNITIVE SCORING#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*Cognitive_Scoring*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    if user == "Chris":
        pattern_to_remove = pattern + 'Cognitive_Scoring_'
        df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
        df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
        df['filename'] = df['filename'].astype(int)
        dfs.append(df)
    elif user == "Ty":
        pattern_to_remove = path1+r"\Cognitive_Scoring_"
        for x in range(len(df['filename'])):
            df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
            df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
            df['filename'][x] = int(df['filename'][x])
            dfs.append(df)
    
cog_scoring = pd.concat(dfs, ignore_index=True)
cog_scoring = cog_scoring.sort_values(by='filename', ascending=False)
cog_scoring = cog_scoring.drop(columns=['filename'])
cog_scoring = cog_scoring.drop_duplicates(subset='GlobalRecordId', keep='first')

cog_scoring.to_csv("CSV_Merged/Cog_Scoring.csv")

####HOUSEHOLD CHILD#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*_household*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    if user == "Chris":
        pattern_to_remove = pattern + '_household_'
        df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
        df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
        df['filename'] = df['filename'].astype(int)
        dfs.append(df)
    elif user == "Ty":
        pattern_to_remove = path1+r"\_household_"
        for x in range(len(df['filename'])):
            df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
            df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
            df['filename'][x] = int(df['filename'][x])
            dfs.append(df)
    
household_child = pd.concat(dfs, ignore_index=True)
household_child = household_child.sort_values(by='filename', ascending=False)
household_child = household_child.drop(columns=['filename'])
household_child = household_child.drop_duplicates(subset='GlobalRecordId', keep='first')

household_child.to_csv("CSV_Merged/Household_Child.csv")

####HOUSEHOLD PARENT#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*Familiar*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    if user == "Chris":
        pattern_to_remove = pattern + 'Familiar_'
        df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
        df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
        df['filename'] = df['filename'].astype(int)
        dfs.append(df)
    elif user == "Ty":
        pattern_to_remove = path1+r"\Familiar_"
        for x in range(len(df['filename'])):
            df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
            df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
            df['filename'][x] = int(df['filename'][x])
            dfs.append(df)
    
household_parent = pd.concat(dfs, ignore_index=True)
household_parent = household_parent.sort_values(by='filename', ascending=False)
household_parent = household_parent.drop(columns=['filename'])
household_parent = household_parent.drop_duplicates(subset='GlobalRecordId', keep='first')

household_parent.to_csv("CSV_Merged/Household_Parent.csv")

####PHYS CHILD#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*_physical_exam*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    if user == "Chris":
        pattern_to_remove = pattern + '_physical_exam_'
        df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
        df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
        df['filename'] = df['filename'].astype(int)
        dfs.append(df)
    elif user == "Ty":
        pattern_to_remove = path1+r"\_physical_exam_"
        for x in range(len(df['filename'])):
            df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
            df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
            df['filename'][x] = int(df['filename'][x])
            dfs.append(df)
    
phys_child = pd.concat(dfs, ignore_index=True)
phys_child = phys_child.sort_values(by='filename', ascending=False)
phys_child = phys_child.drop(columns=['filename'])
phys_child = phys_child.drop_duplicates(subset='GlobalRecordId', keep='first')

phys_child.to_csv("CSV_Merged/Phys_Child.csv")

####PHYS PARENT#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*Examen_Físico*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    if user == "Chris":
        pattern_to_remove = pattern + 'Examen_Físico_'
        df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
        df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
        df['filename'] = df['filename'].astype(int)
        dfs.append(df)
    elif user == "Ty":
        pattern_to_remove = path1+r"\Examen_Físico_"
        for x in range(len(df['filename'])):
            df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
            df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
            df['filename'][x] = int(df['filename'][x])
            dfs.append(df)
    
phys_parent = pd.concat(dfs, ignore_index=True)
phys_parent = phys_parent.sort_values(by='filename', ascending=False)
phys_parent = phys_parent.drop(columns=['filename'])
phys_parent = phys_parent.drop_duplicates(subset='GlobalRecordId', keep='first')

phys_parent.to_csv("CSV_Merged/Phys_Parent.csv")

####INFOR CHILD#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*_informant*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    if user == "Chris":
        pattern_to_remove = pattern + '_informant_'
        df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
        df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
        df['filename'] = df['filename'].astype(int)
        dfs.append(df)
    elif user == "Ty":
        pattern_to_remove = path1+r"\_informant_"
        for x in range(len(df['filename'])):
            df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
            df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
            df['filename'][x] = int(df['filename'][x])
            dfs.append(df)
    
infor_child = pd.concat(dfs, ignore_index=True)
infor_child = infor_child.sort_values(by='filename', ascending=False)
infor_child = infor_child.drop(columns=['filename'])
infor_child = infor_child.drop_duplicates(subset='GlobalRecordId', keep='first')

infor_child.to_csv("CSV_Merged/Infor_Child.csv")

####INFOR PARENT#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*Informante*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    if user == "Chris":
        pattern_to_remove = pattern + 'Informante_'
        df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
        df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
        df['filename'] = df['filename'].astype(int)
        dfs.append(df)
    elif user == "Ty":
        pattern_to_remove = path1+r"\Informante_"
        for x in range(len(df['filename'])):
            df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
            df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
            df['filename'][x] = int(df['filename'][x])
            dfs.append(df)
    
infor_parent = pd.concat(dfs, ignore_index=True)
infor_parent = infor_parent.sort_values(by='filename', ascending=False)
infor_parent = infor_parent.drop(columns=['filename'])
infor_parent = infor_parent.drop_duplicates(subset='GlobalRecordId', keep='first')

infor_parent.to_csv("CSV_Merged/Infor_Parent.csv")

####SOCIO CHILD#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*_sociodemographic*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    if user == "Chris":
        pattern_to_remove = pattern + '_sociodemographic_'
        df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
        df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
        df['filename'] = df['filename'].astype(int)
        dfs.append(df)
    elif user == "Ty":
        pattern_to_remove = path1+r"\_sociodemographic_"
        for x in range(len(df['filename'])):
            df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
            df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
            df['filename'][x] = int(df['filename'][x])
            dfs.append(df)
    
socio_child = pd.concat(dfs, ignore_index=True)
socio_child = socio_child.sort_values(by='filename', ascending=False)
socio_child = socio_child.drop(columns=['filename'])
socio_child = socio_child.drop_duplicates(subset='GlobalRecordId', keep='first')

socio_child.to_csv("CSV_Merged/Socio_Child.csv")

####SOCIO PARENT#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*Sociodemográfica*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    if user == "Chris":
        pattern_to_remove = pattern + 'Sociodemográfica_'
        df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
        df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
        df['filename'] = df['filename'].astype(int)
        dfs.append(df)
    elif user == "Ty":
        pattern_to_remove = path1+r"\Sociodemográfica_"
        for x in range(len(df['filename'])):
            df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
            df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
            df['filename'][x] = int(df['filename'][x])
            dfs.append(df)
    
socio_parent = pd.concat(dfs, ignore_index=True)
socio_parent = socio_parent.sort_values(by='filename', ascending=False)
socio_parent = socio_parent.drop(columns=['filename'])
socio_parent = socio_parent.drop_duplicates(subset='GlobalRecordId', keep='first')

socio_parent.to_csv("CSV_Merged/Socio_Parent.csv")

####NEIGHBORHOOD#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*Neighborhood*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    if user == "Chris":
        pattern_to_remove = pattern + 'Neighborhood_'
        df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
        df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
        df['filename'] = df['filename'].astype(int)
        dfs.append(df)
    elif user == "Ty":
        pattern_to_remove = path1+r"\Neighborhood_"
        for x in range(len(df['filename'])):
            df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
            df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
            df['filename'][x] = int(df['filename'][x])
            dfs.append(df)
    
neighborhood = pd.concat(dfs, ignore_index=True)
neighborhood = neighborhood.sort_values(by='filename', ascending=False)
neighborhood = neighborhood.drop(columns=['filename'])
neighborhood = neighborhood.drop_duplicates(subset='GlobalRecordId', keep='first')

neighborhood.to_csv("CSV_Merged/Neighborhood.csv")

####DOOR PARENT#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*Door*.csv')):
    if 'information' not in filename.lower():
        print(f"Processing {filename}")
        df = pd.read_csv(filename)
        df['filename'] = filename
        if user == "Chris":
            pattern_to_remove = pattern + 'Door_'
            df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
            df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
            df['filename'] = df['filename'].astype(int)
            dfs.append(df)
        elif user == "Ty":
            pattern_to_remove = path1+r"\Door_"
            for x in range(len(df['filename'])):
                df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
                df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
                df['filename'][x] = int(df['filename'][x])
                dfs.append(df)
    
door_parent = pd.concat(dfs, ignore_index=True)
door_parent = door_parent.sort_values(by='filename', ascending=False)
door_parent = door_parent.drop(columns=['filename'])
door_parent = door_parent.drop_duplicates(subset='GlobalRecordId', keep='first')

door_parent.to_csv("CSV_Merged/Door.csv")

####DOOR CHILD 1#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*_informationdoor_*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    if user == "Chris":
        pattern_to_remove = pattern + '_informationdoor_'
        df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
        df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
        df['filename'] = df['filename'].astype(int)
        dfs.append(df)
    elif user == "Ty":
        pattern_to_remove = path1+r"\_informationdoor_"
        for x in range(len(df['filename'])):
            df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
            df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
            df['filename'][x] = int(df['filename'][x])
            dfs.append(df)
    
informationdoor = pd.concat(dfs, ignore_index=True)

informationdoor['D_HOUSEID'] = informationdoor.groupby('GlobalRecordId')['D_HOUSEID'].transform(lambda x: x.ffill().bfill())
informationdoor['D_CLUSTID'] = informationdoor.groupby('GlobalRecordId')['D_CLUSTID'].transform(lambda x: x.ffill().bfill())
informationdoor['D_INTERID'] = informationdoor.groupby('GlobalRecordId')['D_INTERID'].transform(lambda x: x.ffill().bfill())
informationdoor = informationdoor.drop_duplicates(subset='GlobalRecordId', keep='first')
informationdoor = informationdoor.sort_values(by='filename', ascending=False)
informationdoor = informationdoor.drop(columns=['filename'])
informationdoor.to_csv("CSV_Merged/InformationDoor.csv")

####DOOR CHILD 2#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*_informationdoorparticipants*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    if user == "Chris":
        pattern_to_remove = pattern + '_informationdoorparticipants_'
        df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
        df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
        df['filename'] = df['filename'].astype(int)
        dfs.append(df)
    elif user == "Ty":
        pattern_to_remove = path1+r"\_informationdoorparticipants_"
        for x in range(len(df['filename'])):
            df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
            df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
            df['filename'][x] = int(df['filename'][x])
            dfs.append(df)
    
informationdoorparticipants = pd.concat(dfs, ignore_index=True)

informationdoorparticipants = informationdoorparticipants.drop_duplicates(subset='GlobalRecordId', keep='first')
informationdoorparticipants = informationdoorparticipants.sort_values(by='filename', ascending=False)
informationdoorparticipants = informationdoorparticipants.drop(columns=['filename'])
informationdoorparticipants.to_csv("CSV_Merged/InformationDoorParticipants.csv")

####ROSTER PARENT#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*Listas*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    if user == "Chris":
        pattern_to_remove = pattern + 'Listas_'
        df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
        df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
        df['filename'] = df['filename'].astype(int)
        dfs.append(df)
    elif user == "Ty":
        pattern_to_remove = path1+r"\Listas_"
        for x in range(len(df['filename'])):
            df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
            df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
            df['filename'][x] = int(df['filename'][x])
            dfs.append(df)
    
rosters_parent = pd.concat(dfs, ignore_index=True)
rosters_parent = rosters_parent.sort_values(by='filename', ascending=False)
rosters_parent = rosters_parent.drop(columns=['filename'])
rosters_parent = rosters_parent.drop_duplicates(subset='GlobalRecordId', keep='first')

rosters_parent.to_csv("CSV_Merged/Roster_Parent.csv")

####ROSTER CHILD 1#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*_mainhousehold*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    if user == "Chris":
        pattern_to_remove = pattern + '_mainhousehold_'
        df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
        df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
        df['filename'] = df['filename'].astype(int)
        dfs.append(df)
    elif user == "Ty":
        pattern_to_remove = path1+r"\_mainhousehold_"
        for x in range(len(df['filename'])):
            df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
            df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
            df['filename'][x] = int(df['filename'][x])
            dfs.append(df)
    
mainhousehold = pd.concat(dfs, ignore_index=True)
mainhousehold = mainhousehold.sort_values(by='filename', ascending=False)
mainhousehold = mainhousehold.drop(columns=['filename'])
mainhousehold = mainhousehold.drop_duplicates(subset='GlobalRecordId', keep='first')

mainhousehold.to_csv("CSV_Merged/MainHousehold.csv")

####ROSTER CHILD 2#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*_participants*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    if user == "Chris":
        pattern_to_remove = pattern + '_participants_'
        df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
        df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
        df['filename'] = df['filename'].astype(int)
        dfs.append(df)
    elif user == "Ty":
        pattern_to_remove = path1+r"\_participants_"
        for x in range(len(df['filename'])):
            df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
            df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
            df['filename'][x] = int(df['filename'][x])
            dfs.append(df)
    
participants = pd.concat(dfs, ignore_index=True)
participants = participants.sort_values(by='filename', ascending=False)
participants = participants.drop(columns=['filename'])
participants = participants.drop_duplicates(subset='GlobalRecordId', keep='first')

participants.to_csv("CSV_Merged/Participants.csv")

####ROSTER CHILD 3#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*_rosterhousehold*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    if user == "Chris":
        pattern_to_remove = pattern + '_rosterhousehold_'
        df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
        df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
        df['filename'] = df['filename'].astype(int)
        dfs.append(df)
    elif user == "Ty":
        pattern_to_remove = path1+r"\_rosterhousehold_"
        for x in range(len(df['filename'])):
            df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
            df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
            df['filename'][x] = int(df['filename'][x])
            dfs.append(df)
    
nonparticipants = pd.concat(dfs, ignore_index=True)
nonparticipants = nonparticipants.sort_values(by='filename', ascending=False)
nonparticipantrs = nonparticipants.drop(columns=['filename'])
nonparticipants = nonparticipants.drop_duplicates(subset='GlobalRecordId', keep='first')

nonparticipants.to_csv("CSV_Merged/NonParticipants.csv")

####ROSTER CHILD 4#######

dfs = [] 

for filename in glob.glob(os.path.join(folder_path, '*_nonresidentchildren*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    if user == "Chris":
        pattern_to_remove = pattern + '_nonresidentchildren_'
        df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
        df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
        df['filename'] = df['filename'].astype(int)
        dfs.append(df)
    elif user == "Ty":
        pattern_to_remove = path1+r"\_nonresidentchildren_"
        for x in range(len(df['filename'])):
            df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
            df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
            df['filename'][x] = int(df['filename'][x])
            dfs.append(df)
    
nonresidentchildren = pd.concat(dfs, ignore_index=True)
nonresidentchildren = nonresidentchildren.sort_values(by='filename', ascending=False)
nonresidentchildren = nonresidentchildren.drop(columns=['filename'])
nonresidentchildren = nonresidentchildren.drop_duplicates(subset='GlobalRecordId', keep='first')

nonresidentchildren.to_csv("CSV_Merged/NonResidentChildren.csv")

if country != "CU":
    dfs = []  # list to hold all dataframes
    for filename in glob.glob(os.path.join(folder_path, '*Sangre*.csv')):
        print(f"Processing {filename}")
        df = pd.read_csv(filename)
        df['filename'] = filename
        if user == "Chris":
            pattern_to_remove = pattern + 'Sangre_'
            df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
            df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
            df['filename'] = df['filename'].astype(int)
            dfs.append(df)
        elif user == "Ty":
            pattern_to_remove = path1+r"\Sangre_"
            for x in range(len(df['filename'])):
                df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
                df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
                df['filename'][x] = int(df['filename'][x])
                dfs.append(df)
        
    sangre = pd.concat(dfs, ignore_index=True)
    sangre = sangre.sort_values(by='filename', ascending=False)
    sangre = sangre.drop(columns=['filename'])
    sangre = sangre.drop_duplicates(subset='GlobalRecordId', keep='first')
    
    sangre.to_csv("CSV_Merged/Sangre.csv")
# Out:
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202308070426_0_03_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202307140648_0_03_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202309070711_0_04_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202309070650_0_02_DO.csv
# <ipython-input-8-93de204843a8>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
# <ipython-input-8-93de204843a8>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
# <ipython-input-8-93de204843a8>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename'][x] = int(df['filename'][x])
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202309091031_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202311060248_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202311060217_1_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202311060217_0_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202311181014_1_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202311181014_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202311181019_0_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202311181020_1_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202311181015_0_03_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202308021158_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202308020801_0_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202312020257_1_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202312020301_0_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202312020258_0_04_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202312020302_1_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202312020248_0_05_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202310260836_0_05_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202312020256_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202309070704_0_03_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202310240653_0_03_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202310240647_0_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202305070627_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202307080158_0_03_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202307140639_0_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202307140630_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202307080016_0_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202307080154_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\_cognitive_202308020801_0_02_DO 2.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202308070426_0_03_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202307140648_0_03_DO.csv
# <ipython-input-8-93de204843a8>:217: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
# <ipython-input-8-93de204843a8>:218: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
# <ipython-input-8-93de204843a8>:219: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename'][x] = int(df['filename'][x])
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202309070712_0_04_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202309091031_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202309070649_0_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202311060248_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202311060217_0_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202311060217_1_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202311181015_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202311181018_1_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202311181018_0_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202311181014_0_03_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202308021159_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202312020305_0_04_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202312020247_0_05_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202312020258_0_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202310260836_0_05_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202312020257_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202312020258_1_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202312020257_1_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202309070703_0_03_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202310240653_0_03_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202310240646_0_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202307140639_0_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202305070627_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202307140630_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202307080015_0_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202307080155_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202308020801_0_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitiva_202308020801_0_02_DO 2.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202308070426_0_03_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202307140648_0_03_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202309070649_0_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202309070712_0_04_DO.csv
# <ipython-input-8-93de204843a8>:247: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename'][x] = str(df['filename'][x].replace(pattern_to_remove, ""))
# <ipython-input-8-93de204843a8>:248: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename'][x] = re.sub(r'_.*', '', str(df['filename'][x]))
# <ipython-input-8-93de204843a8>:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['filename'][x] = int(df['filename'][x])
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202309091031_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202311060248_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202311060217_0_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202311060217_1_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202311181015_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202311181018_0_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202311181019_1_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202311181014_0_03_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202308021159_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202312020257_1_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202312020258_1_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202312020258_0_02_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202312020305_0_04_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202312020257_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202312020248_0_05_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202310260836_0_05_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_202305070627_0_01_DO.csv
# Processing G:\.shortcut-targets-by-id\1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo\CADAS data upload\Rep Dom\All_CSVs\Cognitive_Scoring_