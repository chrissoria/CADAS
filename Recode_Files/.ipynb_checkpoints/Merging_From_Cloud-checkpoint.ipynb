# %%
import os,glob
import pandas as pd
import numpy as np

# %%
os.chdir('/Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Rep Dom/Sync Files + Media/10_28_23_cloud/__EpiInfo')
current_directory = os.getcwd()
print(current_directory)
file_list = os.listdir(current_directory)
# Out:
# /Users/chrissoria/Library/CloudStorage/GoogleDrive-chrissoria@berkeley.edu/.shortcut-targets-by-id/1W2cJLOLxbqzOAwJhLhGSqwAfzOjg0nTo/CADAS data upload/Rep Dom/Sync Files + Media/10_28_23_cloud/__EpiInfo

# %%
file_list
# Out:
# ['Sangre',
#  'Listas',
#  'participants',
#  'cognitive',
#  '.DS_Store',
#  'informationdoorparticipants',
#  'nonresidentchildren',
#  'Informante',
#  'informant',
#  'Examen_Físico',
#  'Cognitive_Scoring',
#  'mainhousehold',
#  'Cognitiva',
#  'Familiar',
#  'Neighborhood',
#  'rosterhousehold',
#  'household',
#  'informationdoor',
#  'physical_exam',
#  'Sociodemográfica',
#  'Door',
#  'sociodemographic']

# %%
# Initialize an empty DataFrame to hold all rows
master_df = pd.DataFrame()

# Change directory to where the files are located
os.chdir('/Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Rep Dom/Sync Files + Media/10_28_23_cloud/__EpiInfo/Sangre')

# List all files in the directory
file_list = os.listdir()

# Loop through each file in the directory
for file_name in file_list:
    # Check if the file is a .txt file
    if file_name.endswith('.txt'):
        # Read the content of the file
        with open(file_name, 'r') as f:
            file_content = f.read()
        
        # Parse the JSON content to a Python dictionary
        data_dict = json.loads(file_content)
        
        # Create a DataFrame from the dictionary
        df = pd.DataFrame([data_dict])
        
        # Append this DataFrame to the master DataFrame
        master_df = master_df.append(df, ignore_index=True)

# Now master_df contains all rows, one for each file
print(master_df)

# Save master_df to a CSV file
master_df.to_csv('combined_data.csv', index=False)

# Initialize an empty DataFrame to hold all rows
master_df = pd.DataFrame()

# Change directory to where the files are located
os.chdir('/Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Rep Dom/Sync Files + Media/10_28_23_cloud/__EpiInfo/cognitive')

# List all files in the directory
file_list = os.listdir()

# Loop through each file in the directory
for file_name in file_list:
    # Check if the file is a .txt file
    if file_name.endswith('.txt'):
        # Read the content of the file
        with open(file_name, 'r') as f:
            file_content = f.read()
            
            if not file_content.strip():
                print(f"Skipping empty file: {file_name}")
                continue
        
        # Parse the JSON content to a Python dictionary
        data_dict = json.loads(file_content)
        
        # Create a DataFrame from the dictionary
        df = pd.DataFrame([data_dict])
        
        # Append this DataFrame to the master DataFrame
        master_df = master_df.append(df, ignore_index=True)

# Now master_df contains all rows, one for each file
print(master_df)

# Save master_df to a CSV file
master_df.to_csv('combined_data.csv', index=False)
# Out:
#      _updateStamp SA_CLUSTID SA_PARTICID SA_HOUSEID  \
# 0   1695607250608         78           1         51
# 1   1692396795480         09           1        101
# 2   1694307904487         10           1         21
# 3   1695607512375         78           1         10
# 22  8/25/2023 12:00:00 a. m.  7:40:00 a. m.  8/25/2023 12:00:00 a. m.
# 23  8/10/2023 12:00:00 a. m.  8:05:00 a. m.  8/10/2023 12:00:00 a. m.
# 24  9/14/2023 12:00:00 a. m.  7:45:00 a. m.  9/14/2023 12:00:00 a. m.
# 25  8/10/2023 12:00:00 a. m.  6:26:00 a. m.  8/10/2023 12:00:00 a. m.
# 26  8/31/2023 12:00:00 a. m.  8:20:00 a. m.  8/31/2023 12:00:00 a. m.
# 27  8/25/2023 12:00:00 a. m.  8:33:00 a. m.  8/25/2023 12:00:00 a. m.
# 28  8/10/2023 12:00:00 a. m.  7:23:00 a. m.  8/10/2023 12:00:00 a. m.
# 29  8/25/2023 12:00:00 a. m.  7:00:00 a. m.  8/25/2023 12:00:00 a. m.
# 30  8/31/2023 12:00:00 a. m.  8:55:00 a. m.  8/31/2023 12:00:00 a. m.
# 31  8/18/2023 12:00:00 a. m.  8:00:00 a. m.  8/18/2023 12:00:00 a. m.
# 32  9/14/2023 12:00:00 a. m.  8:15:00 a. m.  9/14/2023 12:00:00 a. m.
# 33  8/31/2023 12:00:00 a. m.  8:35:00 a. m.  8/31/2023 12:00:00 a. m.
# 34  8/10/2023 12:00:00 a. m.  6:27:00 a. m.  8/10/2023 12:00:00 a. m.
#
#              SA_4b SA_INTERID  _syncStatus
# 0    8:50:00 a. m.          2          NaN
# 1    9:36:00 p. m.          3          0.0
# 2                           2          NaN
# 3    9:45:00 a. m.          2          NaN
# 4                           2          NaN
# 5    8:00:00 a. m.          2          NaN
# 6    8:00:00 a. m.          2          NaN
# 7    8:50:00 a. m.          2          NaN
# 8    8:00:00 a. m.          2          NaN
# 9    6:26:00 a. m.          2          NaN
# 10                          2          NaN
# 11                          2          NaN
# 12   8:10:00 a. m.          2          NaN
# 13   9:35:00 a. m.          2          NaN
# 14                          2          NaN
# 15   6:26:00 a. m.          2          NaN
# 16   9:35:00 a. m.          2          NaN
# 17   8:50:00 a. m.          2          NaN
# 18   8:10:00 a. m.          2          NaN
# 19   6:26:00 a. m.          2          NaN
# 20   8:50:00 a. m.          2          NaN
# 21   8:00:00 a. m.          2          NaN
# 22   8:00:00 a. m.          2          NaN
# 23   8:36:00 a. m.          2          NaN
# 24   8:50:00 a. m.          2          NaN
# 25   6:27:00 a. m.          2          NaN
# 26   9:00:00 a. m.          2          NaN
# 27   9:35:00 a. m.          2          NaN
# 28  10:30:00 a. m.          2          NaN
# 29   8:00:00 a. m.          2          NaN
# 30   9:20:00 a. m.          2          NaN
# 31   8:10:00 a. m.          2          NaN
# 32   8:50:00 p. m.          2          NaN
# 33   9:00:00 a. m.          2          NaN
# 34   6:27:00 a. m.          2          NaN
# Skipping empty file: d6b9993f-a396-4b3b-b06d-8885c641e5c4.txt
# Skipping empty file: 4bf096ba-bb87-4e69-b17d-42c0b3c6133c.txt
# Skipping empty file: 8e9d6171-4631-4851-ab5b-57a29bd42a8b.txt
#        C_DATE_END                                           SYMB_PIC  \
# 0                  /sdcard/Download/EpiInfo/Images/1691593561260.jpg
# 1     20 oct 2023  /sdcard/Download/EpiInfo/Images/1697825482740.jpg
# 2
# 3             NaN
# 4             NaN  /sdcard/Download/EpiInfo/Images/1688148385786.jpg
# ..            ...                                                ...
# 124           NaN  /sdcard/Download/EpiInfo/Images/1688481927873.jpg
# 125  11 sept 2023  /sdcard/Download/EpiInfo/Images/1694458770700.jpg
# 126   6 sept 2023  /sdcard/Download/EpiInfo/Images/1694027570003.jpg
# 127   11 oct 2023  /sdcard/Download/EpiInfo/Images/1697034723871.jpg
# 128                /sdcard/Download/EpiInfo/Images/1690480004764.jpg
#
#                                              G_2_File2      C_TIME10_1  \
# 0    /sdcard/Download/EpiInfo/Media/59923951-023b-4...
# 1    /sdcard/Download/EpiInfo/Media/38653b62-35d7-4...   8:35:19 p. m.
# 2                                                        7:30:58 p. m.
# 3    /sdcard/Download/EpiInfo/Media/b479f281-a424-4...             NaN
# 4    /sdcard/Download/EpiInfo/Media/fea7df1b-70c2-4...             NaN
# ..                                                 ...             ...
# 124  /sdcard/Download/EpiInfo/Media/54783b33-21b1-4...             NaN
# 125  /sdcard/Download/EpiInfo/Media/753c51cf-f03d-4...   8:15:26 p. m.
# 126  /sdcard/Download/EpiInfo/Media/05f52481-62b4-4...   4:48:12 p. m.
# 127  /sdcard/Download/EpiInfo/Media/57f9cc5f-1aab-4...  10:43:42 a. m.
# 128  /sdcard/Download/EpiInfo/Media/ecc750f6-ea23-4...  10:23:12 a. m.
#
#          C_TIME11_1      C_TIME_END  \
# 0                     3:12:43 p. m.
# 1     8:35:21 p. m.   2:24:11 p. m.
# 2     7:30:59 p. m.   8:05:27 p. m.
# 3               NaN   7:32:48 a. m.
# 4               NaN   2:48:37 p. m.
# ..              ...             ...
# 124             NaN   4:44:03 p. m.
# 125   8:15:28 p. m.   3:14:13 p. m.
# 126   4:48:35 p. m.   3:35:43 p. m.
# 127  10:44:16 a. m.  10:48:00 a. m.
# 128  10:23:18 a. m.  12:40:55 p. m.
#
#                                             C_79_4_PIC   _updateStamp  \
# 0    /sdcard/Download/EpiInfo/Images/1691594679599.jpg  1692790413698
# 1    /sdcard/Download/EpiInfo/Images/1697826233533.jpg  1697848530273
# 2                                                       1693667962721
# 3    /sdcard/Download/EpiInfo/Images/1689950910521.jpg  1690026445946
# 4    /sdcard/Download/EpiInfo/Images/1688149601786.jpg  1689200701851
# ..                                                 ...            ...
# 124                                                     1688780733076
# 125  /sdcard/Download/EpiInfo/Images/1694459616707.jpg  1694477732695
