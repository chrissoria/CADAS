# %%
import os,glob
import pandas as pd
import numpy as np
import re

# %% [markdown]
# change country between: PR, DR, CU

# %%
user = "Chris"
country = "CU"

# %%
CU_directory = r"/Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba"
DR_directory = r"/Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Rep Dom"
PR_directory = r"/Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Puerto_Rico"

if user == "Chris":
    if country == "DR":
        current_directory = DR_directory
        path1 = DR_directory+"/All_CSVs" #where all CSVs are located
        path2 = DR_directory+"/Sync Files/28.03.24/CSV/" #change to show latest upload
        imagepath = DR_directory+"/All_Image_Files"
        audiopath = DR_directory+"/All_Audio_Files"
    elif country == "CU":
        current_directory = CU_directory
        path1 = CU_directory+"/All_CSVs" #where we merge all cumulative CSV files into one file
        imagepath = CU_directory+"/All_Image_Files"
        audiopath = CU_directory+"/All_Audio_Files"
        path2 = CU_directory+"/Sync_Files/04_27_24/CSV" #where we check to see that the latest batch of data includes all files it should
    elif country == "PR":
        current_directory = PR_directory
        path1 = PR_directory+"/All_CSVs"
        path2 = PR_directory+"/Sync Files/03_22_24/CSV/"
        imagepath = PR_directory+"/All_Image_Files"
        audiopath = PR_directory+"/All_Audio_Files"
elif user == "Ty":
    current_directory = r"C:\Users\Ty\Desktop\DataExport"
else:
    print("Unknown user. Cannot set directory.")
    current_directory = None

if current_directory:
    os.chdir(current_directory)
    file_list = os.listdir(current_directory)
    print(f"Changed directory to: {current_directory}")
    print(path1)
    print(path2)
    print(file_list)
    
imagenames = os.listdir(imagepath)
audionames = os.listdir(audiopath)
# Out:
# Changed directory to: /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba
# /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs
# /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/Sync_Files/04_27_24/CSV
# ['CSV_Merged', '.DS_Store', 'All_Audio_Files', 'Resumen', 'Figures', 'Interviewers.gsheet', 'All_Image_Files', 'Sync_Files', 'All_CSVs']

# %% [markdown]
# Received files document

# %%
# Get the list of all files in the latest file upload
dir_list1 = os.listdir(path2)

# To see which files I received from the data manager (for now not doing anything with this)
newdir_list1 = [x for x in dir_list1 if x.endswith('.epi7')]

# To see which files I was able to process with Epi Info tool
dir_list2 = os.listdir(path2)
newdir_list2 = [x for x in dir_list2 if x.endswith('.csv')]

def remove_common(a, b):
    for i in a[:]:
        if i in b:
            a.remove(i)
            b.remove(i)

    print("list1 : ", a)
    print("list2 : ", b)

remove_common(newdir_list1, newdir_list2)

words_to_filter = ["Neighborhood", "Door", "_informationdoor_", "_informationdoorparticipants", "Listas", "_mainhousehold", "_participants", "_rosterhousehold", "_nonresidentchildren", "Cognitva", "_cognitive", "Cognitive_Scoring", "Examen_Físico", "_physical_exam","Familiar", "_household", "Informante", "_informant"]

# breaking the longer list into smaller lists
filtered_lists = {word: [] for word in words_to_filter}

for text in newdir_list2:
    for word in words_to_filter:
        if word in text:
            filtered_lists[word].append(text)

# change this number depending on how many tablets worth of information you're receiving
for word, filtered_list in filtered_lists.items():
    while len(filtered_list) < 10:
        filtered_list.append("Blanco")

Received_Files = pd.DataFrame()

for word, filtered_list in filtered_lists.items():
    Received_Files[word] = pd.Series(filtered_list)

Received_Files.to_excel(path2+'/Received_Files_Checklist.xlsx', index=False)

Received_Files
# Out:
# list1 :  []
# list2 :  ['Familiar_202404250410_0_02_CU.csv', 'Examen_Físico_202404250410_0_02_CU.csv', 'Sample_Contact_Investigation_202404250410_0_02_CU.csv', '_mainhousehold_202404250410_0_02_CU.csv', '_nonresidentchildren_202404250410_0_02_CU.csv', '_rosterhousehold_202404250410_0_02_CU.csv', '_cognitive_202404250409_0_02_CU.csv', 'Cognitive_Scoring_202404250410_0_02_CU.csv', 'Listas_202404250410_0_02_CU.csv', '_household_202404250409_0_02_CU.csv', '_sociodemographic_202404250410_0_02_CU.csv', '_participants_202404250410_0_02_CU.csv', '_physical_exam_202404250410_0_02_CU.csv', 'Cognitiva_202404250410_0_02_CU.csv', 'Informante_202404250410_0_02_CU.csv', 'Sociodemográfica_202404250409_0_02_CU.csv', '_informant_202404250409_0_02_CU.csv']
#   Neighborhood    Door _informationdoor_ _informationdoorparticipants  \
# 0       Blanco  Blanco            Blanco                       Blanco
# 1       Blanco  Blanco            Blanco                       Blanco
# 2       Blanco  Blanco            Blanco                       Blanco
# 3       Blanco  Blanco            Blanco                       Blanco
# 4       Blanco  Blanco            Blanco                       Blanco
# 5       Blanco  Blanco            Blanco                       Blanco
# 6       Blanco  Blanco            Blanco                       Blanco
# 7       Blanco  Blanco            Blanco                       Blanco
# 8       Blanco  Blanco            Blanco                       Blanco
# 9       Blanco  Blanco            Blanco                       Blanco
#
#                             Listas                           _mainhousehold  \
# 0  Listas_202404250410_0_02_CU.csv  _mainhousehold_202404250410_0_02_CU.csv
# 1                           Blanco                                   Blanco
# 2                           Blanco                                   Blanco
# 3                           Blanco                                   Blanco
# 4                           Blanco                                   Blanco
# 5                           Blanco                                   Blanco
# 6                           Blanco                                   Blanco
# 7                           Blanco                                   Blanco
# 8                           Blanco                                   Blanco
# 9                           Blanco                                   Blanco
#
#                             _participants  \
# 0  _participants_202404250410_0_02_CU.csv
# 1                                  Blanco
# 2                                  Blanco
# 3                                  Blanco
# 4                                  Blanco
# 5                                  Blanco
# 6                                  Blanco
# 7                                  Blanco
# 8                                  Blanco
# 9                                  Blanco
#
#                             _rosterhousehold  \
# 0  _rosterhousehold_202404250410_0_02_CU.csv
# 1                                     Blanco
# 2                                     Blanco
# 3                                     Blanco
# 4                                     Blanco
# 5                                     Blanco
# 6                                     Blanco
# 7                                     Blanco
# 8                                     Blanco
# 9                                     Blanco
#
#                             _nonresidentchildren Cognitva  \
# 0  _nonresidentchildren_202404250410_0_02_CU.csv   Blanco
# 1                                         Blanco   Blanco
# 2                                         Blanco   Blanco
# 3                                         Blanco   Blanco
# 4                                         Blanco   Blanco
# 5                                         Blanco   Blanco
# 6                                         Blanco   Blanco
# 7                                         Blanco   Blanco
# 8                                         Blanco   Blanco
# 9                                         Blanco   Blanco
#
#                             _cognitive  \
# 0  _cognitive_202404250409_0_02_CU.csv
# 1                               Blanco
# 2                               Blanco
# 3                               Blanco
# 4                               Blanco
# 5                               Blanco
# 6                               Blanco
# 7                               Blanco
# 8                               Blanco
# 9                               Blanco
#
#                             Cognitive_Scoring  \
# 0  Cognitive_Scoring_202404250410_0_02_CU.csv
# 1                                      Blanco
# 2                                      Blanco
# 3                                      Blanco
# 4                                      Blanco
# 5                                      Blanco
# 6                                      Blanco
# 7                                      Blanco
# 8                                      Blanco
# 9                                      Blanco
#
#                             Examen_Físico  \
# 0  Examen_Físico_202404250410_0_02_CU.csv
# 1                                   Blanco
# 2                                   Blanco
# 3                                   Blanco
# 4                                   Blanco
# 5                                   Blanco
# 6                                   Blanco
# 7                                   Blanco
# 8                                   Blanco
# 9                                   Blanco
#
#                             _physical_exam                           Familiar  \
# 0  _physical_exam_202404250410_0_02_CU.csv  Familiar_202404250410_0_02_CU.csv
# 1                                   Blanco                             Blanco
# 2                                   Blanco                             Blanco
# 3                                   Blanco                             Blanco
# 4                                   Blanco                             Blanco
# 5                                   Blanco                             Blanco
# 6                                   Blanco                             Blanco
# 7                                   Blanco                             Blanco
# 8                                   Blanco                             Blanco
# 9                                   Blanco                             Blanco
#
#                             _household                           Informante  \
# 0  _household_202404250409_0_02_CU.csv  Informante_202404250410_0_02_CU.csv
# 1                               Blanco                               Blanco
# 2                               Blanco                               Blanco
# 3                               Blanco                               Blanco
# 4                               Blanco                               Blanco
# 5                               Blanco                               Blanco
# 6                               Blanco                               Blanco
# 7                               Blanco                               Blanco
# 8                               Blanco                               Blanco
# 9                               Blanco                               Blanco
#
#                             _informant
# 0  _informant_202404250409_0_02_CU.csv
# 1                               Blanco
# 2                               Blanco
# 3                               Blanco
# 4                               Blanco
# 5                               Blanco
# 6                               Blanco
# 7                               Blanco
# 8                               Blanco
# 9                               Blanco

# %%
if user == "Chris":
    if country == "CU":
        pattern = "/Users/chrissoria/Google Drive/Other Computers/My Laptop \(1\)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/"
    elif country == "DR":
        pattern = "/Users/chrissoria/Google Drive/Other Computers/My Laptop \(1\)/documents/cadas/data/CADAS data upload/Rep \Dom/All_CSVs/"
    elif country == "PR":
        pattern = "/Users/chrissoria/Google Drive/Other Computers/My Laptop \(1\)/documents/cadas/data/CADAS data upload/Puerto_Rico/All_CSVs/"
elif user == "Ty":
    if country == "CU":
        pattern = r"C:\Users\Ty\Desktop\DataExport/"
    elif country == "DR":
        pattern = r"C:\Users\Ty\Desktop\DataExport/"
else:
    print("Unknown user. Cannot set directory.")
    current_directory = None

folder_path = path1 #goes through this whole folder

####COGNITIVE CHILD#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*_cognitive*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    pattern_to_remove = pattern + "_cognitive_"
    df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
    df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
    df['filename'] = df['filename'].astype(int)
    dfs.append(df)
    
cog_child = pd.concat(dfs, ignore_index=True)
cog_child = cog_child.sort_values(by='filename', ascending=False)
cog_child = cog_child.drop(columns=['filename'])
cog_child = cog_child.drop_duplicates(subset='GlobalRecordId', keep='first')
pattern_to_remove = r'=HYPERLINK\("media\\([^"]+)",\"<CLICK HERE>"\)'
cog_child = cog_child.replace(pattern_to_remove, r'\1', regex=True)

if country == "CU":
    cog_child['C_72_1_PIC'] = np.nan
    cog_child['C_72_2_PIC'] = np.nan
    cog_child['C_72_3_PIC'] = np.nan
    cog_child['C_79_1_PIC'] = np.nan
    cog_child['C_79_2_PIC'] = np.nan
    cog_child['C_79_3_PIC'] = np.nan

columns_to_check = [
    'C_72_1_PIC', 'C_72_2_PIC', 'C_72_3_PIC', 'C_72_4_PIC',
    'C_79_1_PIC', 'C_79_2_PIC', 'C_79_3_PIC', 'C_79_4_PIC',
    'ANIM_PIC', 'SYMB_PIC', 'PENT_PIC',
    'G_1_File', 'G_2_File', 'G_2_File2', 'G_3_File', 'G_3_File2'
]

for column in columns_to_check:
    foundlist = []
    piclist = cog_child[column].tolist()
    file_list = audionames if 'File' in column else imagenames

    for pic in piclist:
        if pic in file_list:
            foundlist.append("found")
        else:
            foundlist.append("missing")

    cog_child[column + '_FOUND'] = foundlist

for column in cog_child.columns:
    if "TIME" in column:
        # Apply transformation to each cell in the column
        cog_child[column] = cog_child[column].apply(lambda x: re.sub(r'(.*?:.*?):..', r'\1', x) if pd.notnull(x) else x)
        
cog_child.to_csv("CSV_Merged/Cog_Child.csv")

####COGNITIVE PARENT#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*Cognitiva*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    pattern_to_remove = pattern + 'Cognitiva_'
    df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
    df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
    df['filename'] = df['filename'].astype(int)
    dfs.append(df)
    
cog_parent = pd.concat(dfs, ignore_index=True)
cog_parent = cog_parent.sort_values(by='filename', ascending=False)
cog_parent = cog_parent.drop(columns=['filename'])
cog_parent = cog_parent.drop_duplicates(subset='GlobalRecordId', keep='first')

cog_parent.to_csv("CSV_Merged/Cog_Parent.csv")

####COGNITIVE SCORING#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*Cognitive_Scoring*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    pattern_to_remove = pattern + 'Cognitive_Scoring_'
    df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
    df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
    df['filename'] = df['filename'].astype(int)
    dfs.append(df)
    
cog_scoring = pd.concat(dfs, ignore_index=True)
cog_scoring = cog_scoring.sort_values(by='filename', ascending=False)
cog_scoring = cog_scoring.drop(columns=['filename'])
cog_scoring = cog_scoring.drop_duplicates(subset='GlobalRecordId', keep='first')

for column in cog_scoring.columns:
    if "TIME" in column:
        # Apply transformation to each cell in the column
        cog_scoring[column] = cog_scoring[column].apply(lambda x: re.sub(r'(.*?:.*?):..', r'\1', x) if pd.notnull(x) else x)

cog_scoring.to_csv("CSV_Merged/Cog_Scoring.csv")

####HOUSEHOLD CHILD#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*_household*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    pattern_to_remove = pattern + '_household_'
    df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
    df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
    df['filename'] = df['filename'].astype(int)
    dfs.append(df)
    
household_child = pd.concat(dfs, ignore_index=True)
household_child = household_child.sort_values(by='filename', ascending=False)
household_child = household_child.drop(columns=['filename'])
household_child = household_child.drop_duplicates(subset='GlobalRecordId', keep='first')

for column in household_child.columns:
    if "TIME" in column:
        # Apply transformation to each cell in the column
        household_child[column] = household_child[column].apply(lambda x: re.sub(r'(.*?:.*?):..', r'\1', x) if pd.notnull(x) else x)


household_child.to_csv("CSV_Merged/Household_Child.csv")

####HOUSEHOLD PARENT#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*Familiar*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    pattern_to_remove = pattern + 'Familiar_'
    df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
    df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
    df['filename'] = df['filename'].astype(int)
    dfs.append(df)
    
household_parent = pd.concat(dfs, ignore_index=True)
household_parent = household_parent.sort_values(by='filename', ascending=False)
household_parent = household_parent.drop(columns=['filename'])
household_parent = household_parent.drop_duplicates(subset='GlobalRecordId', keep='first')

household_parent.to_csv("CSV_Merged/Household_Parent.csv")

####PHYS CHILD#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*_physical_exam*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    pattern_to_remove = pattern + '_physical_exam_'
    df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
    df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
    df['filename'] = df['filename'].astype(int)
    dfs.append(df)
    
phys_child = pd.concat(dfs, ignore_index=True)
phys_child = phys_child.sort_values(by='filename', ascending=False)
phys_child = phys_child.drop(columns=['filename'])
phys_child = phys_child.drop_duplicates(subset='GlobalRecordId', keep='first')

for column in phys_child.columns:
    if "TIME" in column:
        # Apply transformation to each cell in the column
        phys_child[column] = phys_child[column].apply(lambda x: re.sub(r'(.*?:.*?):..', r'\1', x) if pd.notnull(x) else x)


phys_child.to_csv("CSV_Merged/Phys_Child.csv")

####PHYS PARENT#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*Examen_Físico*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    pattern_to_remove = pattern + 'Examen_Físico_'
    df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
    df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
    df['filename'] = df['filename'].astype(int)
    dfs.append(df)
    
phys_parent = pd.concat(dfs, ignore_index=True)
phys_parent = phys_parent.sort_values(by='filename', ascending=False)
phys_parent = phys_parent.drop(columns=['filename'])
phys_parent = phys_parent.drop_duplicates(subset='GlobalRecordId', keep='first')

phys_parent.to_csv("CSV_Merged/Phys_Parent.csv")

####INFOR CHILD#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*_informant*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    pattern_to_remove = pattern + '_informant_'
    df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
    df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
    df['filename'] = df['filename'].astype(int)
    dfs.append(df)
    
infor_child = pd.concat(dfs, ignore_index=True)
infor_child = infor_child.sort_values(by='filename', ascending=False)
infor_child = infor_child.drop(columns=['filename'])
infor_child = infor_child.drop_duplicates(subset='GlobalRecordId', keep='first')

for column in infor_child.columns:
    if "TIME" in column:
        # Apply transformation to each cell in the column
        infor_child[column] = infor_child[column].apply(lambda x: re.sub(r'(.*?:.*?):..', r'\1', x) if pd.notnull(x) else x)


infor_child.to_csv("CSV_Merged/Infor_Child.csv")

####INFOR PARENT#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*Informante*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    pattern_to_remove = pattern + 'Informante_'
    df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
    df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
    df['filename'] = df['filename'].astype(int)
    dfs.append(df)
    
infor_parent = pd.concat(dfs, ignore_index=True)
infor_parent = infor_parent.sort_values(by='filename', ascending=False)
infor_parent = infor_parent.drop(columns=['filename'])
infor_parent = infor_parent.drop_duplicates(subset='GlobalRecordId', keep='first')

infor_parent.to_csv("CSV_Merged/Infor_Parent.csv")

####SOCIO CHILD#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*_sociodemographic*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    pattern_to_remove = pattern + '_sociodemographic_'
    df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
    df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
    df['filename'] = df['filename'].astype(int)
    dfs.append(df)
    
socio_child = pd.concat(dfs, ignore_index=True)
socio_child = socio_child.sort_values(by='filename', ascending=False)
socio_child = socio_child.drop(columns=['filename'])
socio_child = socio_child.drop_duplicates(subset='GlobalRecordId', keep='first')

for column in socio_child.columns:
    if "TIME" in column:
        # Apply transformation to each cell in the column
        socio_child[column] = socio_child[column].apply(lambda x: re.sub(r'(.*?:.*?):..', r'\1', x) if pd.notnull(x) else x)


socio_child.to_csv("CSV_Merged/Socio_Child.csv")

####SOCIO PARENT#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*Sociodemográfica*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    pattern_to_remove = pattern + 'Sociodemográfica_'
    df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
    df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
    df['filename'] = df['filename'].astype(int)
    dfs.append(df)
    
socio_parent = pd.concat(dfs, ignore_index=True)
socio_parent = socio_parent.sort_values(by='filename', ascending=False)
socio_parent = socio_parent.drop(columns=['filename'])
socio_parent = socio_parent.drop_duplicates(subset='GlobalRecordId', keep='first')

socio_parent.to_csv("CSV_Merged/Socio_Parent.csv")

####NEIGHBORHOOD#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*Neighborhood*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    pattern_to_remove = pattern + 'Neighborhood_'
    df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
    df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
    df['filename'] = df['filename'].astype(int)
    dfs.append(df)
    
neighborhood = pd.concat(dfs, ignore_index=True)
neighborhood = neighborhood.sort_values(by='filename', ascending=False)
neighborhood = neighborhood.drop(columns=['filename'])
neighborhood = neighborhood.drop_duplicates(subset='GlobalRecordId', keep='first')

neighborhood.to_csv("CSV_Merged/Neighborhood.csv")

####DOOR PARENT#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*Door*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    pattern_to_remove = pattern + 'Door_'
    df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
    df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
    df['filename'] = df['filename'].astype(int)
    dfs.append(df)
    
door_parent = pd.concat(dfs, ignore_index=True)
door_parent = door_parent.sort_values(by='filename', ascending=False)
door_parent = door_parent.drop(columns=['filename'])
door_parent = door_parent.drop_duplicates(subset='GlobalRecordId', keep='first')

door_parent.to_csv("CSV_Merged/Door.csv")

####DOOR CHILD 1#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*_informationdoor_*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    pattern_to_remove = pattern + '_informationdoor_'
    df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
    df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
    df['filename'] = df['filename'].astype(int)
    dfs.append(df)
    
informationdoor = pd.concat(dfs, ignore_index=True)

informationdoor['D_HOUSEID'] = informationdoor.groupby('GlobalRecordId')['D_HOUSEID'].transform(lambda x: x.ffill().bfill())
informationdoor['D_CLUSTID'] = informationdoor.groupby('GlobalRecordId')['D_CLUSTID'].transform(lambda x: x.ffill().bfill())
informationdoor['D_INTERID'] = informationdoor.groupby('GlobalRecordId')['D_INTERID'].transform(lambda x: x.ffill().bfill())
informationdoor = informationdoor.drop_duplicates(subset='GlobalRecordId', keep='first')
informationdoor = informationdoor.sort_values(by='filename', ascending=False)
informationdoor = informationdoor.drop(columns=['filename'])
informationdoor.to_csv("CSV_Merged/InformationDoor.csv")

####DOOR CHILD 2#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*_informationdoorparticipants*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    pattern_to_remove = pattern + '_informationdoorparticipants_'
    df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
    df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
    df['filename'] = df['filename'].astype(int)
    dfs.append(df)
    
informationdoorparticipants = pd.concat(dfs, ignore_index=True)

informationdoorparticipants = informationdoorparticipants.drop_duplicates(subset='GlobalRecordId', keep='first')
informationdoorparticipants = informationdoorparticipants.sort_values(by='filename', ascending=False)
informationdoorparticipants = informationdoorparticipants.drop(columns=['filename'])
informationdoorparticipants.to_csv("CSV_Merged/InformationDoorParticipants.csv")

####ROSTER PARENT#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*Listas*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    pattern_to_remove = pattern + 'Listas_'
    df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
    df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
    df['filename'] = df['filename'].astype(int)
    dfs.append(df)
    
rosters_parent = pd.concat(dfs, ignore_index=True)
rosters_parent = rosters_parent.sort_values(by='filename', ascending=False)
rosters_parent = rosters_parent.drop(columns=['filename'])
rosters_parent = rosters_parent.drop_duplicates(subset='GlobalRecordId', keep='first')

rosters_parent.to_csv("CSV_Merged/Roster_Parent.csv")

####ROSTER CHILD 1#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*_mainhousehold*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    pattern_to_remove = pattern + '_mainhousehold_'
    df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
    df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
    df['filename'] = df['filename'].astype(int)
    dfs.append(df)
    
mainhousehold = pd.concat(dfs, ignore_index=True)
mainhousehold = mainhousehold.sort_values(by='filename', ascending=False)
mainhousehold = mainhousehold.drop(columns=['filename'])
mainhousehold = mainhousehold.drop_duplicates(subset='GlobalRecordId', keep='first')

mainhousehold.to_csv("CSV_Merged/MainHousehold.csv")

####ROSTER CHILD 2#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*_participants*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    pattern_to_remove = pattern + '_participants_'
    df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
    df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
    df['filename'] = df['filename'].astype(int)
    dfs.append(df)
    
participants = pd.concat(dfs, ignore_index=True)
participants = participants.sort_values(by='filename', ascending=False)
participants = participants.drop(columns=['filename'])
participants = participants.drop_duplicates(subset='GlobalRecordId', keep='first')

participants.to_csv("CSV_Merged/Participants.csv")

####ROSTER CHILD 3#######

dfs = []

for filename in glob.glob(os.path.join(folder_path, '*_rosterhousehold*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    pattern_to_remove = pattern + '_rosterhousehold_'
    df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
    df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
    df['filename'] = df['filename'].astype(int)
    dfs.append(df)
    
nonparticipants = pd.concat(dfs, ignore_index=True)
nonparticipants = nonparticipants.sort_values(by='filename', ascending=False)
nonparticipantrs = nonparticipants.drop(columns=['filename'])
nonparticipants = nonparticipants.drop_duplicates(subset='GlobalRecordId', keep='first')

nonparticipants.to_csv("CSV_Merged/NonParticipants.csv")

####ROSTER CHILD 4#######

dfs = [] 

for filename in glob.glob(os.path.join(folder_path, '*_nonresidentchildren*.csv')):

    print(f"Processing {filename}")
    df = pd.read_csv(filename)
    df['filename'] = filename
    pattern_to_remove = pattern + '_nonresidentchildren_'
    df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
    df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
    df['filename'] = df['filename'].astype(int)
    dfs.append(df)
    
nonresidentchildren = pd.concat(dfs, ignore_index=True)
nonresidentchildren = nonresidentchildren.sort_values(by='filename', ascending=False)
nonresidentchildren = nonresidentchildren.drop(columns=['filename'])
nonresidentchildren = nonresidentchildren.drop_duplicates(subset='GlobalRecordId', keep='first')

nonresidentchildren.to_csv("CSV_Merged/NonResidentChildren.csv")

if country != "CU":
    dfs = []  # list to hold all dataframes
    for filename in glob.glob(os.path.join(folder_path, '*Sangre*.csv')):
        print(f"Processing {filename}")
        df = pd.read_csv(filename)
        df['filename'] = filename
        pattern_to_remove = pattern + 'Sangre_'
        df['filename'] = df['filename'].str.replace(pattern_to_remove, '', regex=True)
        df['filename'] = df['filename'].str.replace(r'_.*', '', regex=True)
        df['filename'] = df['filename'].astype(int)
        dfs.append(df)
        
    sangre = pd.concat(dfs, ignore_index=True)
    sangre = sangre.sort_values(by='filename', ascending=False)
    sangre = sangre.drop(columns=['filename'])
    sangre = sangre.drop_duplicates(subset='GlobalRecordId', keep='first')
    
    sangre.to_csv("CSV_Merged/Sangre.csv")
# Out:
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202404130533_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202307150814_0_20_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202306260819_0_10_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202403220333_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202404170136_0_12_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202307170227_0_05_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202307170227_0_05_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202404130329_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202312150437_0_04_CU[49].csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202404120236_1_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202312150327_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202404130251_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202302240559_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202306280819_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202303170156_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202307150809_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202312151130_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202307150807_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202403220333_1_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202404120129_0_07_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202312150437_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202307250108_0_10_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202404130329_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202404120236_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202404250409_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202401260730_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202310170439_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202309180514_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202403020932_0_11_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202303240546_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202307150809_0_08_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202312151130_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202402240616_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202307150807_0_01_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202402251014_1_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202404160200_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202309130828_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202403220342_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202310200831_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202403220333_2_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202401091138_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202306280819_0_04_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202307150814_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202310180803_1_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202401090022_0_05_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202309120917_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202401260732_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202401090959_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202308091059_0_09_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202402240247_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202401090957_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202312150452_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202403220345_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202310170451_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202402240210_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202402251014_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202401091137_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202404160200_1_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202403310217_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202403020933_0_11_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202404120236_2_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202311020949_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202306290808_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202404120145_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202404120251_0_05_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202403220345_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202309120918_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202402240210_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202306290808_0_06_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_cognitive_202312150452_1_01_CU.csv
# /var/folders/89/6bdxzk2j30v5n3wstywbcpg80000gn/T/ipykernel_19178/2314162121.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cog_child[column + '_FOUND'] = foundlist
# /var/folders/89/6bdxzk2j30v5n3wstywbcpg80000gn/T/ipykernel_19178/2314162121.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cog_child[column + '_FOUND'] = foundlist
# /var/folders/89/6bdxzk2j30v5n3wstywbcpg80000gn/T/ipykernel_19178/2314162121.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cog_child[column + '_FOUND'] = foundlist
# /var/folders/89/6bdxzk2j30v5n3wstywbcpg80000gn/T/ipykernel_19178/2314162121.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cog_child[column + '_FOUND'] = foundlist
# /var/folders/89/6bdxzk2j30v5n3wstywbcpg80000gn/T/ipykernel_19178/2314162121.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cog_child[column + '_FOUND'] = foundlist
# /var/folders/89/6bdxzk2j30v5n3wstywbcpg80000gn/T/ipykernel_19178/2314162121.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cog_child[column + '_FOUND'] = foundlist
# /var/folders/89/6bdxzk2j30v5n3wstywbcpg80000gn/T/ipykernel_19178/2314162121.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cog_child[column + '_FOUND'] = foundlist
# /var/folders/89/6bdxzk2j30v5n3wstywbcpg80000gn/T/ipykernel_19178/2314162121.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cog_child[column + '_FOUND'] = foundlist
# /var/folders/89/6bdxzk2j30v5n3wstywbcpg80000gn/T/ipykernel_19178/2314162121.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cog_child[column + '_FOUND'] = foundlist
# /var/folders/89/6bdxzk2j30v5n3wstywbcpg80000gn/T/ipykernel_19178/2314162121.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cog_child[column + '_FOUND'] = foundlist
# /var/folders/89/6bdxzk2j30v5n3wstywbcpg80000gn/T/ipykernel_19178/2314162121.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cog_child[column + '_FOUND'] = foundlist
# /var/folders/89/6bdxzk2j30v5n3wstywbcpg80000gn/T/ipykernel_19178/2314162121.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cog_child[column + '_FOUND'] = foundlist
# /var/folders/89/6bdxzk2j30v5n3wstywbcpg80000gn/T/ipykernel_19178/2314162121.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cog_child[column + '_FOUND'] = foundlist
# /var/folders/89/6bdxzk2j30v5n3wstywbcpg80000gn/T/ipykernel_19178/2314162121.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cog_child[column + '_FOUND'] = foundlist
# /var/folders/89/6bdxzk2j30v5n3wstywbcpg80000gn/T/ipykernel_19178/2314162121.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cog_child[column + '_FOUND'] = foundlist
# /var/folders/89/6bdxzk2j30v5n3wstywbcpg80000gn/T/ipykernel_19178/2314162121.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cog_child[column + '_FOUND'] = foundlist
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202403220346_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202404160200_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202309130828_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202401091138_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202401090022_0_05_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202309120917_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202401090959_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202308091100_0_09_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202403220334_1_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202402240247_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202404170137_0_12_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202402240210_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202401090957_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202307170227_0_05_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202403220346_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202310170452_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202404160200_1_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202401091137_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202307150809_0_08_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202311020949_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202403020933_0_11_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202309180515_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202307150815_0_20_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202310180803_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202302240600_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202404120145_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202306290808_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202404120251_0_05_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202403220334_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202402240210_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202309120918_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202307170227_0_05_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202306260819_0_10_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202312150453_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202404130533_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202401090958_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202403020931_0_11_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202404130329_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202401260733_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202404130251_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202404120236_1_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202306280819_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202403020934_0_11_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202306280819_0_04_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202307150809_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202303170156_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202307150815_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202312150437_0_04_CU[61].csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202307150807_0_01_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202403220343_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202307150807_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202312151130_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202312150453_1_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202404120129_0_07_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202312150328_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202309270732_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202306290808_0_06_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202404130329_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202307250108_0_10_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202310200826_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202312150437_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202404120236_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202404250410_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202401260730_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202310170439_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202303240546_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202402240616_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202402251015_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitiva_202312151130_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202307170227_0_05_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202306260819_0_10_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202404130533_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202312150453_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202404130251_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202404120236_1_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202403020931_0_11_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202401090958_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202307150809_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202307150815_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202303170156_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202404130330_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202310180804_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202307150815_0_20_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202307150807_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202312151130_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202307150809_0_08_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202402251015_1_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202312150437_0_04_CU[23].csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202403220343_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202307170227_0_05_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202309270732_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202312150453_1_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202404120129_0_07_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202312150328_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202404120236_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202307250108_0_10_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202310200826_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202312150437_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202404130330_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202404250410_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202401260730_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202310170439_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202402240616_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202402251015_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202312151130_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202303240546_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202404160200_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202403220346_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202401090022_0_05_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202401091138_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202401090959_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202308091100_0_09_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202404170137_0_12_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202402240210_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202401090957_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202306290808_0_06_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202403220334_1_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202402240247_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202401091137_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202404160200_1_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202307150807_0_01_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202403220346_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202310170452_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202311020949_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202403020933_0_11_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202309180515_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202404120251_0_05_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202302240600_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202404130330_2_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202404120145_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202306290808_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202402240210_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202309120918_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/Cognitive_Scoring_202403220334_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202402251014_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202401091137_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202311020949_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202403020933_0_11_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202306290808_0_06_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202310180803_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202302240600_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202404120145_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202306290808_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202404120251_0_05_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202403220345_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202309120918_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202402240210_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202404160200_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202309130828_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202310200831_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202403220342_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202401091138_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202307150814_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202401090022_0_05_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202307150807_0_01_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202401260732_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202309120917_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202401090959_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202308091059_0_09_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202402240247_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202306280819_0_04_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202403220345_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202310170451_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202402240210_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202401090957_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202312150452_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202404120129_0_07_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202403220333_1_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202307250108_0_10_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202404130329_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202312150437_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202404120236_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202307150809_0_08_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202404250409_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202401260730_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202310170439_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202309180514_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202403020932_0_11_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202303240546_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202402240616_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202312151130_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202403220333_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202307170227_0_05_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202404170136_0_12_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_household_202404130533_0_03_CU.csv
# ...
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202401091138_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202401090022_0_05_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202310170452_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202403220346_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202307150809_0_08_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202309130828_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202404160200_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202307170227_0_05_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202310200832_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202403220334_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202312150437_0_04_CU[28].csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202309120918_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202402240210_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202307150814_0_20_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202404120145_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202302240600_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202306290808_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202404120251_0_05_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202311020949_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202309180515_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202403020933_0_11_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202404130329_2_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202310180803_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_rosterhousehold_202403220346_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202403220346_2_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202307150807_0_01_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202404120129_0_07_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202312150453_1_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202307150809_1_08_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202306280819_0_04_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202404120236_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202312150438_0_04_CU[98].csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202404130329_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202307250108_0_10_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202307150809_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202401260730_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202404250410_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202312151130_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202402251015_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202402240616_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202303240546_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202402240210_2_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202312150438_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202306260819_0_10_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202404130533_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202312150453_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202307170227_0_05_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202312150327_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202404120236_1_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202404130251_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202401260733_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202404130329_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202307250108_1_10_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202401090958_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202401091139_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202307150809_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202303170156_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202306280819_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202307150807_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202312151130_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202306290808_0_06_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202403220343_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202307150814_0_20_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202307170227_0_05_CU (1).csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202403220346_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202310180803_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202404130329_2_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202309180515_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202403020933_0_11_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202311020949_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202404120251_0_05_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202306290808_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202404120145_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202302240600_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202402240210_0_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202309120918_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202310170451_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202403220334_0_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202309130828_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202404160200_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202403220346_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202401090022_0_05_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202307150814_0_20_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202401091138_0_04_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202308091100_0_09_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202401090959_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202309120917_0_06_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202401090957_0_03_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202402240210_1_08_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202404170137_0_12_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202402240247_0_02_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202403220334_1_01_CU.csv
# Processing /Users/chrissoria/Google Drive/Other Computers/My Laptop (1)/documents/cadas/data/CADAS data upload/Cuba/All_CSVs/_nonresidentchildren_202307150809_0_08_CU (1).csv
